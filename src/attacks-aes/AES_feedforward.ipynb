# %% [markdown]
# # AES Plaintext Recovery (Feedforward Neural Network)
# In this experiment, the network tries to guess the plaintext from the ciphertext, helped with ascii per-byte correction.

# %% [markdown]
# ## Imports

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from dataset.datasets import AESDatasetCiphertextPlaintext
from pipeline import *
# Out:
# 2023-05-11 17:52:47.504106: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Importing the dataset

# %%
data = AESDatasetCiphertextPlaintext(128, 'small')

train_labels, train_samples, test_labels, test_samples = data.get_data()

# %%
get_dataset_info(train_labels, train_samples, test_labels, test_samples)
# Out:
# ===== Training Labels Shape: (189568, 128)
# ===== Label Shape: (128,)
# ===== Training Samples Shape: (189568, 128)
# ===== Sample Shape: (128,)
# ===== Testing Labels Shape: (81243, 128)
# ===== Testing Samples Shape: (81243, 128)

# %% [markdown]
# ## Creating the model

# %%
# Imports
from keras import Sequential
from keras.layers import Input, Dense, BatchNormalization, LayerNormalization
from keras.optimizers import Adam

# %% [markdown]
# ### Model hyperparameters
# In this code block, we specify most parameters and hyperparameters that will be used in the training of the neural network.

# %%
input_shape = np.shape(train_samples[0])

# output dimension
dim = len(train_labels[0])

# units per hidden layer
units = dim*16

loss_scc = 'sparse_categorical_crossentropy'
loss_mse = 'mse'
loss_bce = 'binary_crossentropy'
# 0.1 to 0.001
lr_schedule = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=0.1,
    decay_steps=500,
    decay_rate=0.01)
optimizer = Adam(learning_rate=0.001)
metrics = ['accuracy', 'binary_accuracy']
epochs = 500
batch_size = 5000

# %% [markdown]
# ### Model
# In this code block, we create the model, according to the parameters and the topology we want to achieve.
# We then compile it specifying the optimizer, the loss and the metrics we want outputted.

# %%
# Type of model
neural_network = Sequential()

# Input layer
neural_network.add(Input(shape=input_shape))

# Hidden layers
#neural_network.add(BatchNormalization())
neural_network.add(Dense(units=units, activation='relu'))



# Output layer
neural_network.add(Dense(units=dim, activation='sigmoid'))

# Summary
neural_network.summary()

# Compile model
neural_network.compile(optimizer=optimizer, loss=loss_mse, metrics=metrics)
# Out:
# Model: "sequential_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_73 (Dense)            (None, 2048)              264192
#
#  dense_74 (Dense)            (None, 128)               262272
#
# =================================================================
# Total params: 526,464
# Trainable params: 526,464
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Training
# In this code block, we train the model. It outputs, for each epoch, the loss and metrics.
#
# This block mostly stays the same.

# %%
history = train_model(neural_network, train_samples, train_labels, 
                      batch_size=batch_size, 
                      epochs=epochs)
# Out:
# Epoch 1/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1784 - accuracy: 0.0159 - binary_accuracy: 0.7258 - val_loss: 0.1714 - val_accuracy: 0.0051 - val_binary_accuracy: 0.7358
# Epoch 2/500
# 35/35 [==============================] - 3s 78ms/step - loss: 0.1719 - accuracy: 0.0020 - binary_accuracy: 0.7347 - val_loss: 0.1709 - val_accuracy: 1.0550e-04 - val_binary_accuracy: 0.7363
# Epoch 3/500
# 35/35 [==============================] - 3s 76ms/step - loss: 0.1715 - accuracy: 1.2895e-04 - binary_accuracy: 0.7350 - val_loss: 0.1707 - val_accuracy: 0.0034 - val_binary_accuracy: 0.7364
# Epoch 4/500
# 35/35 [==============================] - 3s 77ms/step - loss: 0.1714 - accuracy: 0.0163 - binary_accuracy: 0.7351 - val_loss: 0.1707 - val_accuracy: 0.0130 - val_binary_accuracy: 0.7367
# Epoch 5/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1713 - accuracy: 0.0112 - binary_accuracy: 0.7351 - val_loss: 0.1707 - val_accuracy: 0.0191 - val_binary_accuracy: 0.7366
# Epoch 6/500
# 35/35 [==============================] - 3s 78ms/step - loss: 0.1712 - accuracy: 0.0175 - binary_accuracy: 0.7351 - val_loss: 0.1707 - val_accuracy: 0.0076 - val_binary_accuracy: 0.7368
# Epoch 7/500
# 35/35 [==============================] - 3s 77ms/step - loss: 0.1712 - accuracy: 0.0097 - binary_accuracy: 0.7352 - val_loss: 0.1707 - val_accuracy: 0.0189 - val_binary_accuracy: 0.7368
# Epoch 8/500
# 35/35 [==============================] - 3s 78ms/step - loss: 0.1711 - accuracy: 0.0131 - binary_accuracy: 0.7352 - val_loss: 0.1707 - val_accuracy: 0.0126 - val_binary_accuracy: 0.7365
# Epoch 9/500
# 35/35 [==============================] - 3s 81ms/step - loss: 0.1710 - accuracy: 0.0116 - binary_accuracy: 0.7353 - val_loss: 0.1707 - val_accuracy: 0.0050 - val_binary_accuracy: 0.7364
# Epoch 10/500
# 35/35 [==============================] - 3s 78ms/step - loss: 0.1710 - accuracy: 0.0115 - binary_accuracy: 0.7353 - val_loss: 0.1707 - val_accuracy: 0.0137 - val_binary_accuracy: 0.7364
# Epoch 11/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1709 - accuracy: 0.0115 - binary_accuracy: 0.7354 - val_loss: 0.1707 - val_accuracy: 0.0087 - val_binary_accuracy: 0.7362
# Epoch 12/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1709 - accuracy: 0.0116 - binary_accuracy: 0.7354 - val_loss: 0.1707 - val_accuracy: 0.0105 - val_binary_accuracy: 0.7365
# Epoch 13/500
# 35/35 [==============================] - 3s 80ms/step - loss: 0.1708 - accuracy: 0.0115 - binary_accuracy: 0.7356 - val_loss: 0.1707 - val_accuracy: 0.0157 - val_binary_accuracy: 0.7362
# Epoch 14/500
# 35/35 [==============================] - 3s 80ms/step - loss: 0.1707 - accuracy: 0.0132 - binary_accuracy: 0.7357 - val_loss: 0.1708 - val_accuracy: 0.0128 - val_binary_accuracy: 0.7366
# Epoch 15/500
# 35/35 [==============================] - 3s 83ms/step - loss: 0.1706 - accuracy: 0.0097 - binary_accuracy: 0.7358 - val_loss: 0.1708 - val_accuracy: 0.0127 - val_binary_accuracy: 0.7362
# Epoch 16/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1705 - accuracy: 0.0142 - binary_accuracy: 0.7359 - val_loss: 0.1708 - val_accuracy: 0.0145 - val_binary_accuracy: 0.7361
# Epoch 17/500
# 35/35 [==============================] - 3s 81ms/step - loss: 0.1704 - accuracy: 0.0102 - binary_accuracy: 0.7361 - val_loss: 0.1708 - val_accuracy: 0.0152 - val_binary_accuracy: 0.7363
# Epoch 18/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1703 - accuracy: 0.0129 - binary_accuracy: 0.7362 - val_loss: 0.1709 - val_accuracy: 0.0127 - val_binary_accuracy: 0.7354
# Epoch 19/500
# 35/35 [==============================] - 3s 81ms/step - loss: 0.1702 - accuracy: 0.0126 - binary_accuracy: 0.7364 - val_loss: 0.1709 - val_accuracy: 0.0071 - val_binary_accuracy: 0.7356
# Epoch 20/500
# 35/35 [==============================] - 3s 85ms/step - loss: 0.1701 - accuracy: 0.0182 - binary_accuracy: 0.7367 - val_loss: 0.1710 - val_accuracy: 0.0036 - val_binary_accuracy: 0.7356
# Epoch 21/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1700 - accuracy: 0.0139 - binary_accuracy: 0.7369 - val_loss: 0.1710 - val_accuracy: 0.0071 - val_binary_accuracy: 0.7351
# Epoch 22/500
# 35/35 [==============================] - 3s 81ms/step - loss: 0.1699 - accuracy: 0.0128 - binary_accuracy: 0.7371 - val_loss: 0.1712 - val_accuracy: 0.0148 - val_binary_accuracy: 0.7350
# Epoch 23/500
# 35/35 [==============================] - 3s 83ms/step - loss: 0.1698 - accuracy: 0.0108 - binary_accuracy: 0.7373 - val_loss: 0.1712 - val_accuracy: 0.0101 - val_binary_accuracy: 0.7351
# Epoch 24/500
# 35/35 [==============================] - 3s 81ms/step - loss: 0.1696 - accuracy: 0.0122 - binary_accuracy: 0.7376 - val_loss: 0.1713 - val_accuracy: 0.0145 - val_binary_accuracy: 0.7347
# Epoch 25/500
# 35/35 [==============================] - 3s 83ms/step - loss: 0.1695 - accuracy: 0.0140 - binary_accuracy: 0.7378 - val_loss: 0.1713 - val_accuracy: 0.0162 - val_binary_accuracy: 0.7347
# Epoch 26/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1694 - accuracy: 0.0136 - binary_accuracy: 0.7382 - val_loss: 0.1714 - val_accuracy: 0.0083 - val_binary_accuracy: 0.7346
# Epoch 27/500
# 35/35 [==============================] - 3s 83ms/step - loss: 0.1693 - accuracy: 0.0106 - binary_accuracy: 0.7384 - val_loss: 0.1715 - val_accuracy: 0.0137 - val_binary_accuracy: 0.7343
# Epoch 28/500
# 35/35 [==============================] - 3s 81ms/step - loss: 0.1691 - accuracy: 0.0128 - binary_accuracy: 0.7387 - val_loss: 0.1716 - val_accuracy: 0.0103 - val_binary_accuracy: 0.7338
# Epoch 29/500
# 35/35 [==============================] - 3s 81ms/step - loss: 0.1690 - accuracy: 0.0130 - binary_accuracy: 0.7390 - val_loss: 0.1717 - val_accuracy: 0.0101 - val_binary_accuracy: 0.7341
# Epoch 30/500
# 35/35 [==============================] - 3s 84ms/step - loss: 0.1689 - accuracy: 0.0129 - binary_accuracy: 0.7392 - val_loss: 0.1718 - val_accuracy: 0.0110 - val_binary_accuracy: 0.7335
# Epoch 31/500
# 35/35 [==============================] - 3s 81ms/step - loss: 0.1687 - accuracy: 0.0127 - binary_accuracy: 0.7395 - val_loss: 0.1720 - val_accuracy: 0.0116 - val_binary_accuracy: 0.7334
# Epoch 32/500
# 35/35 [==============================] - 3s 81ms/step - loss: 0.1686 - accuracy: 0.0122 - binary_accuracy: 0.7396 - val_loss: 0.1720 - val_accuracy: 0.0189 - val_binary_accuracy: 0.7333
# Epoch 33/500
# 35/35 [==============================] - 3s 80ms/step - loss: 0.1684 - accuracy: 0.0146 - binary_accuracy: 0.7400 - val_loss: 0.1722 - val_accuracy: 0.0106 - val_binary_accuracy: 0.7330
# Epoch 34/500
# 35/35 [==============================] - 3s 81ms/step - loss: 0.1683 - accuracy: 0.0127 - binary_accuracy: 0.7403 - val_loss: 0.1722 - val_accuracy: 0.0104 - val_binary_accuracy: 0.7327
# Epoch 35/500
# 35/35 [==============================] - 3s 83ms/step - loss: 0.1682 - accuracy: 0.0160 - binary_accuracy: 0.7405 - val_loss: 0.1724 - val_accuracy: 0.0104 - val_binary_accuracy: 0.7324
# Epoch 36/500
# 35/35 [==============================] - 3s 80ms/step - loss: 0.1680 - accuracy: 0.0122 - binary_accuracy: 0.7407 - val_loss: 0.1725 - val_accuracy: 0.0056 - val_binary_accuracy: 0.7320
# Epoch 37/500
# 35/35 [==============================] - 3s 81ms/step - loss: 0.1679 - accuracy: 0.0116 - binary_accuracy: 0.7410 - val_loss: 0.1726 - val_accuracy: 0.0167 - val_binary_accuracy: 0.7326
# Epoch 38/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1678 - accuracy: 0.0142 - binary_accuracy: 0.7413 - val_loss: 0.1727 - val_accuracy: 0.0096 - val_binary_accuracy: 0.7321
# Epoch 39/500
# 35/35 [==============================] - 3s 84ms/step - loss: 0.1677 - accuracy: 0.0118 - binary_accuracy: 0.7415 - val_loss: 0.1728 - val_accuracy: 0.0106 - val_binary_accuracy: 0.7317
# Epoch 40/500
# 35/35 [==============================] - 3s 80ms/step - loss: 0.1675 - accuracy: 0.0139 - binary_accuracy: 0.7417 - val_loss: 0.1730 - val_accuracy: 0.0083 - val_binary_accuracy: 0.7315
# Epoch 41/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1674 - accuracy: 0.0132 - binary_accuracy: 0.7419 - val_loss: 0.1731 - val_accuracy: 0.0118 - val_binary_accuracy: 0.7311
# Epoch 42/500
# 35/35 [==============================] - 3s 84ms/step - loss: 0.1673 - accuracy: 0.0140 - binary_accuracy: 0.7422 - val_loss: 0.1732 - val_accuracy: 0.0090 - val_binary_accuracy: 0.7308
# Epoch 43/500
# 35/35 [==============================] - 3s 81ms/step - loss: 0.1672 - accuracy: 0.0122 - binary_accuracy: 0.7423 - val_loss: 0.1733 - val_accuracy: 0.0092 - val_binary_accuracy: 0.7307
# Epoch 44/500
# 35/35 [==============================] - 3s 83ms/step - loss: 0.1670 - accuracy: 0.0173 - binary_accuracy: 0.7426 - val_loss: 0.1734 - val_accuracy: 0.0135 - val_binary_accuracy: 0.7309
# Epoch 45/500
# 35/35 [==============================] - 3s 80ms/step - loss: 0.1669 - accuracy: 0.0153 - binary_accuracy: 0.7429 - val_loss: 0.1736 - val_accuracy: 0.0076 - val_binary_accuracy: 0.7304
# Epoch 46/500
# 35/35 [==============================] - 3s 80ms/step - loss: 0.1668 - accuracy: 0.0147 - binary_accuracy: 0.7431 - val_loss: 0.1736 - val_accuracy: 0.0083 - val_binary_accuracy: 0.7309
# Epoch 47/500
# 35/35 [==============================] - 3s 80ms/step - loss: 0.1666 - accuracy: 0.0140 - binary_accuracy: 0.7434 - val_loss: 0.1737 - val_accuracy: 0.0091 - val_binary_accuracy: 0.7305
# Epoch 48/500
# 35/35 [==============================] - 3s 83ms/step - loss: 0.1665 - accuracy: 0.0112 - binary_accuracy: 0.7437 - val_loss: 0.1739 - val_accuracy: 0.0226 - val_binary_accuracy: 0.7300
# Epoch 49/500
# 35/35 [==============================] - 3s 80ms/step - loss: 0.1664 - accuracy: 0.0152 - binary_accuracy: 0.7438 - val_loss: 0.1740 - val_accuracy: 0.0135 - val_binary_accuracy: 0.7300
# Epoch 50/500
# 35/35 [==============================] - 3s 80ms/step - loss: 0.1663 - accuracy: 0.0150 - binary_accuracy: 0.7441 - val_loss: 0.1741 - val_accuracy: 0.0107 - val_binary_accuracy: 0.7298
# Epoch 51/500
# 35/35 [==============================] - 3s 80ms/step - loss: 0.1662 - accuracy: 0.0127 - binary_accuracy: 0.7442 - val_loss: 0.1742 - val_accuracy: 0.0119 - val_binary_accuracy: 0.7294
# Epoch 52/500
# 35/35 [==============================] - 3s 83ms/step - loss: 0.1661 - accuracy: 0.0128 - binary_accuracy: 0.7444 - val_loss: 0.1744 - val_accuracy: 0.0150 - val_binary_accuracy: 0.7290
# Epoch 53/500
# 35/35 [==============================] - 3s 80ms/step - loss: 0.1660 - accuracy: 0.0143 - binary_accuracy: 0.7447 - val_loss: 0.1744 - val_accuracy: 0.0110 - val_binary_accuracy: 0.7288
# Epoch 54/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1658 - accuracy: 0.0123 - binary_accuracy: 0.7450 - val_loss: 0.1746 - val_accuracy: 0.0140 - val_binary_accuracy: 0.7285
# Epoch 55/500
# 35/35 [==============================] - 3s 80ms/step - loss: 0.1657 - accuracy: 0.0128 - binary_accuracy: 0.7451 - val_loss: 0.1746 - val_accuracy: 0.0148 - val_binary_accuracy: 0.7290
# Epoch 56/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1656 - accuracy: 0.0142 - binary_accuracy: 0.7453 - val_loss: 0.1748 - val_accuracy: 0.0075 - val_binary_accuracy: 0.7285
# Epoch 57/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1655 - accuracy: 0.0132 - binary_accuracy: 0.7455 - val_loss: 0.1748 - val_accuracy: 0.0143 - val_binary_accuracy: 0.7283
# Epoch 58/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1654 - accuracy: 0.0132 - binary_accuracy: 0.7457 - val_loss: 0.1750 - val_accuracy: 0.0167 - val_binary_accuracy: 0.7281
# Epoch 59/500
# 35/35 [==============================] - 3s 80ms/step - loss: 0.1653 - accuracy: 0.0138 - binary_accuracy: 0.7459 - val_loss: 0.1751 - val_accuracy: 0.0152 - val_binary_accuracy: 0.7281
# Epoch 60/500
# 35/35 [==============================] - 3s 83ms/step - loss: 0.1652 - accuracy: 0.0121 - binary_accuracy: 0.7461 - val_loss: 0.1753 - val_accuracy: 0.0137 - val_binary_accuracy: 0.7276
# Epoch 61/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1651 - accuracy: 0.0138 - binary_accuracy: 0.7462 - val_loss: 0.1753 - val_accuracy: 0.0198 - val_binary_accuracy: 0.7276
# Epoch 62/500
# 35/35 [==============================] - 3s 81ms/step - loss: 0.1650 - accuracy: 0.0155 - binary_accuracy: 0.7465 - val_loss: 0.1754 - val_accuracy: 0.0149 - val_binary_accuracy: 0.7272
# Epoch 63/500
# 35/35 [==============================] - 3s 80ms/step - loss: 0.1649 - accuracy: 0.0133 - binary_accuracy: 0.7467 - val_loss: 0.1755 - val_accuracy: 0.0150 - val_binary_accuracy: 0.7272
# Epoch 64/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1648 - accuracy: 0.0141 - binary_accuracy: 0.7469 - val_loss: 0.1755 - val_accuracy: 0.0138 - val_binary_accuracy: 0.7272
# Epoch 65/500
# 35/35 [==============================] - 3s 80ms/step - loss: 0.1647 - accuracy: 0.0133 - binary_accuracy: 0.7469 - val_loss: 0.1757 - val_accuracy: 0.0151 - val_binary_accuracy: 0.7270
# Epoch 66/500
# 35/35 [==============================] - 3s 81ms/step - loss: 0.1646 - accuracy: 0.0154 - binary_accuracy: 0.7472 - val_loss: 0.1758 - val_accuracy: 0.0106 - val_binary_accuracy: 0.7266
# Epoch 67/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1645 - accuracy: 0.0144 - binary_accuracy: 0.7474 - val_loss: 0.1759 - val_accuracy: 0.0110 - val_binary_accuracy: 0.7266
# Epoch 68/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1645 - accuracy: 0.0139 - binary_accuracy: 0.7475 - val_loss: 0.1760 - val_accuracy: 0.0094 - val_binary_accuracy: 0.7262
# Epoch 69/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1643 - accuracy: 0.0142 - binary_accuracy: 0.7477 - val_loss: 0.1760 - val_accuracy: 0.0071 - val_binary_accuracy: 0.7260
# Epoch 70/500
# 35/35 [==============================] - 3s 80ms/step - loss: 0.1643 - accuracy: 0.0131 - binary_accuracy: 0.7479 - val_loss: 0.1761 - val_accuracy: 0.0136 - val_binary_accuracy: 0.7263
# Epoch 71/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1642 - accuracy: 0.0122 - binary_accuracy: 0.7480 - val_loss: 0.1762 - val_accuracy: 0.0232 - val_binary_accuracy: 0.7258
# Epoch 72/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1641 - accuracy: 0.0145 - binary_accuracy: 0.7482 - val_loss: 0.1763 - val_accuracy: 0.0211 - val_binary_accuracy: 0.7258
# Epoch 73/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1640 - accuracy: 0.0135 - binary_accuracy: 0.7484 - val_loss: 0.1765 - val_accuracy: 0.0128 - val_binary_accuracy: 0.7255
# Epoch 74/500
# 35/35 [==============================] - 3s 80ms/step - loss: 0.1640 - accuracy: 0.0143 - binary_accuracy: 0.7485 - val_loss: 0.1766 - val_accuracy: 0.0122 - val_binary_accuracy: 0.7251
# Epoch 75/500
# 35/35 [==============================] - 3s 81ms/step - loss: 0.1639 - accuracy: 0.0130 - binary_accuracy: 0.7487 - val_loss: 0.1766 - val_accuracy: 0.0134 - val_binary_accuracy: 0.7249
# Epoch 76/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1638 - accuracy: 0.0134 - binary_accuracy: 0.7488 - val_loss: 0.1767 - val_accuracy: 0.0107 - val_binary_accuracy: 0.7253
# Epoch 77/500
# 35/35 [==============================] - 3s 81ms/step - loss: 0.1637 - accuracy: 0.0130 - binary_accuracy: 0.7490 - val_loss: 0.1768 - val_accuracy: 0.0161 - val_binary_accuracy: 0.7249
# Epoch 78/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1637 - accuracy: 0.0140 - binary_accuracy: 0.7491 - val_loss: 0.1769 - val_accuracy: 0.0147 - val_binary_accuracy: 0.7247
# Epoch 79/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1636 - accuracy: 0.0138 - binary_accuracy: 0.7491 - val_loss: 0.1771 - val_accuracy: 0.0166 - val_binary_accuracy: 0.7242
# Epoch 80/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1635 - accuracy: 0.0138 - binary_accuracy: 0.7493 - val_loss: 0.1770 - val_accuracy: 0.0165 - val_binary_accuracy: 0.7246
# Epoch 81/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1635 - accuracy: 0.0134 - binary_accuracy: 0.7495 - val_loss: 0.1771 - val_accuracy: 0.0167 - val_binary_accuracy: 0.7246
# Epoch 82/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1634 - accuracy: 0.0143 - binary_accuracy: 0.7497 - val_loss: 0.1772 - val_accuracy: 0.0113 - val_binary_accuracy: 0.7243
# Epoch 83/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1633 - accuracy: 0.0134 - binary_accuracy: 0.7498 - val_loss: 0.1772 - val_accuracy: 0.0105 - val_binary_accuracy: 0.7242
# Epoch 84/500
# 35/35 [==============================] - 3s 83ms/step - loss: 0.1632 - accuracy: 0.0135 - binary_accuracy: 0.7499 - val_loss: 0.1772 - val_accuracy: 0.0159 - val_binary_accuracy: 0.7243
# Epoch 85/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1632 - accuracy: 0.0129 - binary_accuracy: 0.7501 - val_loss: 0.1773 - val_accuracy: 0.0189 - val_binary_accuracy: 0.7242
# Epoch 86/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1631 - accuracy: 0.0152 - binary_accuracy: 0.7502 - val_loss: 0.1775 - val_accuracy: 0.0120 - val_binary_accuracy: 0.7236
# Epoch 87/500
# 35/35 [==============================] - 3s 80ms/step - loss: 0.1631 - accuracy: 0.0130 - binary_accuracy: 0.7502 - val_loss: 0.1777 - val_accuracy: 0.0130 - val_binary_accuracy: 0.7232
# Epoch 88/500
# 35/35 [==============================] - 3s 83ms/step - loss: 0.1630 - accuracy: 0.0152 - binary_accuracy: 0.7504 - val_loss: 0.1776 - val_accuracy: 0.0100 - val_binary_accuracy: 0.7238
# Epoch 89/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1629 - accuracy: 0.0123 - binary_accuracy: 0.7506 - val_loss: 0.1778 - val_accuracy: 0.0176 - val_binary_accuracy: 0.7224
# Epoch 90/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1629 - accuracy: 0.0149 - binary_accuracy: 0.7505 - val_loss: 0.1779 - val_accuracy: 0.0130 - val_binary_accuracy: 0.7227
# Epoch 91/500
# 35/35 [==============================] - 3s 83ms/step - loss: 0.1628 - accuracy: 0.0133 - binary_accuracy: 0.7507 - val_loss: 0.1777 - val_accuracy: 0.0111 - val_binary_accuracy: 0.7233
# Epoch 92/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1628 - accuracy: 0.0132 - binary_accuracy: 0.7509 - val_loss: 0.1780 - val_accuracy: 0.0119 - val_binary_accuracy: 0.7222
# Epoch 93/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1627 - accuracy: 0.0131 - binary_accuracy: 0.7510 - val_loss: 0.1780 - val_accuracy: 0.0152 - val_binary_accuracy: 0.7229
# Epoch 94/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1627 - accuracy: 0.0146 - binary_accuracy: 0.7511 - val_loss: 0.1780 - val_accuracy: 0.0097 - val_binary_accuracy: 0.7225
# Epoch 95/500
# 35/35 [==============================] - 3s 84ms/step - loss: 0.1626 - accuracy: 0.0133 - binary_accuracy: 0.7512 - val_loss: 0.1781 - val_accuracy: 0.0104 - val_binary_accuracy: 0.7229
# Epoch 96/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1626 - accuracy: 0.0138 - binary_accuracy: 0.7514 - val_loss: 0.1781 - val_accuracy: 0.0145 - val_binary_accuracy: 0.7229
# Epoch 97/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1625 - accuracy: 0.0138 - binary_accuracy: 0.7514 - val_loss: 0.1782 - val_accuracy: 0.0158 - val_binary_accuracy: 0.7224
# Epoch 98/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1624 - accuracy: 0.0140 - binary_accuracy: 0.7516 - val_loss: 0.1783 - val_accuracy: 0.0176 - val_binary_accuracy: 0.7222
# Epoch 99/500
# 35/35 [==============================] - 3s 80ms/step - loss: 0.1624 - accuracy: 0.0153 - binary_accuracy: 0.7515 - val_loss: 0.1783 - val_accuracy: 0.0057 - val_binary_accuracy: 0.7219
# Epoch 100/500
# 35/35 [==============================] - 3s 80ms/step - loss: 0.1624 - accuracy: 0.0141 - binary_accuracy: 0.7517 - val_loss: 0.1784 - val_accuracy: 0.0137 - val_binary_accuracy: 0.7220
# Epoch 101/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1623 - accuracy: 0.0139 - binary_accuracy: 0.7518 - val_loss: 0.1786 - val_accuracy: 0.0101 - val_binary_accuracy: 0.7213
# Epoch 102/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1623 - accuracy: 0.0140 - binary_accuracy: 0.7519 - val_loss: 0.1786 - val_accuracy: 0.0224 - val_binary_accuracy: 0.7214
# Epoch 103/500
# 35/35 [==============================] - 3s 80ms/step - loss: 0.1622 - accuracy: 0.0162 - binary_accuracy: 0.7520 - val_loss: 0.1786 - val_accuracy: 0.0087 - val_binary_accuracy: 0.7217
# Epoch 104/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1622 - accuracy: 0.0124 - binary_accuracy: 0.7520 - val_loss: 0.1787 - val_accuracy: 0.0178 - val_binary_accuracy: 0.7208
# Epoch 105/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1621 - accuracy: 0.0152 - binary_accuracy: 0.7521 - val_loss: 0.1786 - val_accuracy: 0.0151 - val_binary_accuracy: 0.7216
# Epoch 106/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1621 - accuracy: 0.0133 - binary_accuracy: 0.7523 - val_loss: 0.1787 - val_accuracy: 0.0135 - val_binary_accuracy: 0.7219
# Epoch 107/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1621 - accuracy: 0.0136 - binary_accuracy: 0.7522 - val_loss: 0.1790 - val_accuracy: 0.0123 - val_binary_accuracy: 0.7206
# Epoch 108/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1620 - accuracy: 0.0139 - binary_accuracy: 0.7524 - val_loss: 0.1787 - val_accuracy: 0.0105 - val_binary_accuracy: 0.7220
# Epoch 109/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1619 - accuracy: 0.0147 - binary_accuracy: 0.7526 - val_loss: 0.1791 - val_accuracy: 0.0227 - val_binary_accuracy: 0.7202
# Epoch 110/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1619 - accuracy: 0.0133 - binary_accuracy: 0.7526 - val_loss: 0.1791 - val_accuracy: 0.0216 - val_binary_accuracy: 0.7205
# Epoch 111/500
# 35/35 [==============================] - 3s 78ms/step - loss: 0.1619 - accuracy: 0.0142 - binary_accuracy: 0.7527 - val_loss: 0.1789 - val_accuracy: 0.0141 - val_binary_accuracy: 0.7215
# Epoch 112/500
# 35/35 [==============================] - 3s 80ms/step - loss: 0.1618 - accuracy: 0.0135 - binary_accuracy: 0.7528 - val_loss: 0.1793 - val_accuracy: 0.0148 - val_binary_accuracy: 0.7209
# Epoch 113/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1618 - accuracy: 0.0138 - binary_accuracy: 0.7527 - val_loss: 0.1790 - val_accuracy: 0.0116 - val_binary_accuracy: 0.7209
# Epoch 114/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1618 - accuracy: 0.0136 - binary_accuracy: 0.7529 - val_loss: 0.1794 - val_accuracy: 0.0159 - val_binary_accuracy: 0.7205
# Epoch 115/500
# 35/35 [==============================] - 3s 78ms/step - loss: 0.1618 - accuracy: 0.0136 - binary_accuracy: 0.7528 - val_loss: 0.1794 - val_accuracy: 0.0130 - val_binary_accuracy: 0.7197
# Epoch 116/500
# 35/35 [==============================] - 3s 83ms/step - loss: 0.1617 - accuracy: 0.0139 - binary_accuracy: 0.7531 - val_loss: 0.1794 - val_accuracy: 0.0131 - val_binary_accuracy: 0.7201
# Epoch 117/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1617 - accuracy: 0.0128 - binary_accuracy: 0.7531 - val_loss: 0.1792 - val_accuracy: 0.0184 - val_binary_accuracy: 0.7211
# Epoch 118/500
# 35/35 [==============================] - 3s 78ms/step - loss: 0.1616 - accuracy: 0.0139 - binary_accuracy: 0.7533 - val_loss: 0.1793 - val_accuracy: 0.0161 - val_binary_accuracy: 0.7203
# Epoch 119/500
# 35/35 [==============================] - 3s 83ms/step - loss: 0.1616 - accuracy: 0.0126 - binary_accuracy: 0.7533 - val_loss: 0.1793 - val_accuracy: 0.0133 - val_binary_accuracy: 0.7205
# Epoch 120/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1615 - accuracy: 0.0135 - binary_accuracy: 0.7534 - val_loss: 0.1796 - val_accuracy: 0.0155 - val_binary_accuracy: 0.7198
# Epoch 121/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1615 - accuracy: 0.0143 - binary_accuracy: 0.7535 - val_loss: 0.1796 - val_accuracy: 0.0140 - val_binary_accuracy: 0.7195
# Epoch 122/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1615 - accuracy: 0.0132 - binary_accuracy: 0.7535 - val_loss: 0.1796 - val_accuracy: 0.0197 - val_binary_accuracy: 0.7194
# Epoch 123/500
# 35/35 [==============================] - 3s 78ms/step - loss: 0.1614 - accuracy: 0.0148 - binary_accuracy: 0.7536 - val_loss: 0.1795 - val_accuracy: 0.0103 - val_binary_accuracy: 0.7207
# Epoch 124/500
# 35/35 [==============================] - 3s 80ms/step - loss: 0.1614 - accuracy: 0.0135 - binary_accuracy: 0.7537 - val_loss: 0.1795 - val_accuracy: 0.0173 - val_binary_accuracy: 0.7195
# Epoch 125/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1613 - accuracy: 0.0140 - binary_accuracy: 0.7538 - val_loss: 0.1797 - val_accuracy: 0.0087 - val_binary_accuracy: 0.7199
# Epoch 126/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1613 - accuracy: 0.0141 - binary_accuracy: 0.7538 - val_loss: 0.1796 - val_accuracy: 0.0081 - val_binary_accuracy: 0.7201
# Epoch 127/500
# 35/35 [==============================] - 3s 83ms/step - loss: 0.1613 - accuracy: 0.0134 - binary_accuracy: 0.7539 - val_loss: 0.1798 - val_accuracy: 0.0151 - val_binary_accuracy: 0.7198
# Epoch 128/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1612 - accuracy: 0.0134 - binary_accuracy: 0.7539 - val_loss: 0.1799 - val_accuracy: 0.0162 - val_binary_accuracy: 0.7191
# Epoch 129/500
# 35/35 [==============================] - 3s 78ms/step - loss: 0.1612 - accuracy: 0.0144 - binary_accuracy: 0.7540 - val_loss: 0.1799 - val_accuracy: 0.0131 - val_binary_accuracy: 0.7191
# Epoch 130/500
# 35/35 [==============================] - 3s 83ms/step - loss: 0.1612 - accuracy: 0.0141 - binary_accuracy: 0.7541 - val_loss: 0.1798 - val_accuracy: 0.0120 - val_binary_accuracy: 0.7194
# Epoch 131/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1612 - accuracy: 0.0145 - binary_accuracy: 0.7541 - val_loss: 0.1800 - val_accuracy: 0.0111 - val_binary_accuracy: 0.7195
# Epoch 132/500
# 35/35 [==============================] - 3s 78ms/step - loss: 0.1611 - accuracy: 0.0135 - binary_accuracy: 0.7541 - val_loss: 0.1802 - val_accuracy: 0.0148 - val_binary_accuracy: 0.7185
# Epoch 133/500
# 35/35 [==============================] - 3s 81ms/step - loss: 0.1611 - accuracy: 0.0135 - binary_accuracy: 0.7542 - val_loss: 0.1802 - val_accuracy: 0.0126 - val_binary_accuracy: 0.7189
# Epoch 134/500
# 35/35 [==============================] - 3s 78ms/step - loss: 0.1611 - accuracy: 0.0136 - binary_accuracy: 0.7542 - val_loss: 0.1804 - val_accuracy: 0.0101 - val_binary_accuracy: 0.7184
# Epoch 135/500
# 35/35 [==============================] - 3s 81ms/step - loss: 0.1611 - accuracy: 0.0136 - binary_accuracy: 0.7542 - val_loss: 0.1800 - val_accuracy: 0.0156 - val_binary_accuracy: 0.7191
# Epoch 136/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1610 - accuracy: 0.0135 - binary_accuracy: 0.7545 - val_loss: 0.1804 - val_accuracy: 0.0131 - val_binary_accuracy: 0.7182
# Epoch 137/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1610 - accuracy: 0.0128 - binary_accuracy: 0.7544 - val_loss: 0.1803 - val_accuracy: 0.0090 - val_binary_accuracy: 0.7180
# Epoch 138/500
# 35/35 [==============================] - 3s 83ms/step - loss: 0.1609 - accuracy: 0.0148 - binary_accuracy: 0.7546 - val_loss: 0.1801 - val_accuracy: 0.0104 - val_binary_accuracy: 0.7190
# Epoch 139/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1610 - accuracy: 0.0129 - binary_accuracy: 0.7545 - val_loss: 0.1803 - val_accuracy: 0.0164 - val_binary_accuracy: 0.7188
# Epoch 140/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1609 - accuracy: 0.0134 - binary_accuracy: 0.7546 - val_loss: 0.1803 - val_accuracy: 0.0137 - val_binary_accuracy: 0.7191
# Epoch 141/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1609 - accuracy: 0.0136 - binary_accuracy: 0.7547 - val_loss: 0.1805 - val_accuracy: 0.0083 - val_binary_accuracy: 0.7178
# Epoch 142/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1609 - accuracy: 0.0142 - binary_accuracy: 0.7547 - val_loss: 0.1807 - val_accuracy: 0.0106 - val_binary_accuracy: 0.7168
# Epoch 143/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1608 - accuracy: 0.0127 - binary_accuracy: 0.7547 - val_loss: 0.1806 - val_accuracy: 0.0206 - val_binary_accuracy: 0.7177
# Epoch 144/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1608 - accuracy: 0.0139 - binary_accuracy: 0.7550 - val_loss: 0.1805 - val_accuracy: 0.0148 - val_binary_accuracy: 0.7182
# Epoch 145/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1607 - accuracy: 0.0139 - binary_accuracy: 0.7550 - val_loss: 0.1804 - val_accuracy: 0.0124 - val_binary_accuracy: 0.7191
# Epoch 146/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1607 - accuracy: 0.0133 - binary_accuracy: 0.7550 - val_loss: 0.1807 - val_accuracy: 0.0116 - val_binary_accuracy: 0.7176
# Epoch 147/500
# 35/35 [==============================] - 3s 81ms/step - loss: 0.1607 - accuracy: 0.0145 - binary_accuracy: 0.7550 - val_loss: 0.1805 - val_accuracy: 0.0186 - val_binary_accuracy: 0.7186
# Epoch 148/500
# 35/35 [==============================] - 3s 78ms/step - loss: 0.1607 - accuracy: 0.0136 - binary_accuracy: 0.7551 - val_loss: 0.1806 - val_accuracy: 0.0224 - val_binary_accuracy: 0.7178
# Epoch 149/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1607 - accuracy: 0.0143 - binary_accuracy: 0.7552 - val_loss: 0.1807 - val_accuracy: 0.0220 - val_binary_accuracy: 0.7179
# Epoch 150/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1606 - accuracy: 0.0147 - binary_accuracy: 0.7552 - val_loss: 0.1809 - val_accuracy: 0.0136 - val_binary_accuracy: 0.7170
# Epoch 151/500
# 35/35 [==============================] - 3s 80ms/step - loss: 0.1606 - accuracy: 0.0138 - binary_accuracy: 0.7552 - val_loss: 0.1810 - val_accuracy: 0.0109 - val_binary_accuracy: 0.7167
# Epoch 152/500
# 35/35 [==============================] - 3s 81ms/step - loss: 0.1606 - accuracy: 0.0136 - binary_accuracy: 0.7553 - val_loss: 0.1808 - val_accuracy: 0.0115 - val_binary_accuracy: 0.7181
# Epoch 153/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1606 - accuracy: 0.0132 - binary_accuracy: 0.7554 - val_loss: 0.1809 - val_accuracy: 0.0093 - val_binary_accuracy: 0.7172
# Epoch 154/500
# 35/35 [==============================] - 3s 83ms/step - loss: 0.1605 - accuracy: 0.0138 - binary_accuracy: 0.7554 - val_loss: 0.1809 - val_accuracy: 0.0081 - val_binary_accuracy: 0.7178
# Epoch 155/500
# 35/35 [==============================] - 3s 78ms/step - loss: 0.1605 - accuracy: 0.0135 - binary_accuracy: 0.7554 - val_loss: 0.1810 - val_accuracy: 0.0129 - val_binary_accuracy: 0.7174
# Epoch 156/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1605 - accuracy: 0.0140 - binary_accuracy: 0.7555 - val_loss: 0.1809 - val_accuracy: 0.0104 - val_binary_accuracy: 0.7176
# Epoch 157/500
# 35/35 [==============================] - 3s 83ms/step - loss: 0.1604 - accuracy: 0.0153 - binary_accuracy: 0.7557 - val_loss: 0.1810 - val_accuracy: 0.0106 - val_binary_accuracy: 0.7174
# Epoch 158/500
# 35/35 [==============================] - 3s 80ms/step - loss: 0.1605 - accuracy: 0.0133 - binary_accuracy: 0.7555 - val_loss: 0.1810 - val_accuracy: 0.0115 - val_binary_accuracy: 0.7171
# Epoch 159/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1604 - accuracy: 0.0134 - binary_accuracy: 0.7556 - val_loss: 0.1812 - val_accuracy: 0.0126 - val_binary_accuracy: 0.7169
# Epoch 160/500
# 35/35 [==============================] - 3s 80ms/step - loss: 0.1604 - accuracy: 0.0138 - binary_accuracy: 0.7556 - val_loss: 0.1810 - val_accuracy: 0.0109 - val_binary_accuracy: 0.7172
# Epoch 161/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1604 - accuracy: 0.0136 - binary_accuracy: 0.7557 - val_loss: 0.1813 - val_accuracy: 0.0128 - val_binary_accuracy: 0.7164
# Epoch 162/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1604 - accuracy: 0.0135 - binary_accuracy: 0.7557 - val_loss: 0.1811 - val_accuracy: 0.0105 - val_binary_accuracy: 0.7175
# Epoch 163/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1603 - accuracy: 0.0132 - binary_accuracy: 0.7558 - val_loss: 0.1813 - val_accuracy: 0.0081 - val_binary_accuracy: 0.7168
# Epoch 164/500
# 35/35 [==============================] - 3s 84ms/step - loss: 0.1603 - accuracy: 0.0135 - binary_accuracy: 0.7559 - val_loss: 0.1811 - val_accuracy: 0.0069 - val_binary_accuracy: 0.7170
# Epoch 165/500
# 35/35 [==============================] - 3s 80ms/step - loss: 0.1602 - accuracy: 0.0146 - binary_accuracy: 0.7560 - val_loss: 0.1814 - val_accuracy: 0.0099 - val_binary_accuracy: 0.7164
# Epoch 166/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1603 - accuracy: 0.0134 - binary_accuracy: 0.7560 - val_loss: 0.1813 - val_accuracy: 0.0139 - val_binary_accuracy: 0.7165
# Epoch 167/500
# 35/35 [==============================] - 3s 81ms/step - loss: 0.1602 - accuracy: 0.0154 - binary_accuracy: 0.7560 - val_loss: 0.1812 - val_accuracy: 0.0134 - val_binary_accuracy: 0.7171
# Epoch 168/500
# 35/35 [==============================] - 3s 80ms/step - loss: 0.1602 - accuracy: 0.0129 - binary_accuracy: 0.7560 - val_loss: 0.1813 - val_accuracy: 0.0128 - val_binary_accuracy: 0.7165
# Epoch 169/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1602 - accuracy: 0.0138 - binary_accuracy: 0.7561 - val_loss: 0.1813 - val_accuracy: 0.0114 - val_binary_accuracy: 0.7174
# Epoch 170/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1601 - accuracy: 0.0140 - binary_accuracy: 0.7562 - val_loss: 0.1814 - val_accuracy: 0.0107 - val_binary_accuracy: 0.7173
# Epoch 171/500
# 35/35 [==============================] - 3s 83ms/step - loss: 0.1602 - accuracy: 0.0142 - binary_accuracy: 0.7561 - val_loss: 0.1814 - val_accuracy: 0.0132 - val_binary_accuracy: 0.7170
# Epoch 172/500
# 35/35 [==============================] - 3s 80ms/step - loss: 0.1601 - accuracy: 0.0132 - binary_accuracy: 0.7562 - val_loss: 0.1814 - val_accuracy: 0.0175 - val_binary_accuracy: 0.7169
# Epoch 173/500
# 35/35 [==============================] - 3s 83ms/step - loss: 0.1601 - accuracy: 0.0151 - binary_accuracy: 0.7563 - val_loss: 0.1814 - val_accuracy: 0.0107 - val_binary_accuracy: 0.7167
# Epoch 174/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1601 - accuracy: 0.0131 - binary_accuracy: 0.7563 - val_loss: 0.1815 - val_accuracy: 0.0147 - val_binary_accuracy: 0.7163
# Epoch 175/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1601 - accuracy: 0.0136 - binary_accuracy: 0.7563 - val_loss: 0.1816 - val_accuracy: 0.0110 - val_binary_accuracy: 0.7162
# Epoch 176/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1601 - accuracy: 0.0133 - binary_accuracy: 0.7563 - val_loss: 0.1816 - val_accuracy: 0.0196 - val_binary_accuracy: 0.7162
# Epoch 177/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1600 - accuracy: 0.0139 - binary_accuracy: 0.7564 - val_loss: 0.1814 - val_accuracy: 0.0124 - val_binary_accuracy: 0.7166
# Epoch 178/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1600 - accuracy: 0.0136 - binary_accuracy: 0.7565 - val_loss: 0.1818 - val_accuracy: 0.0168 - val_binary_accuracy: 0.7154
# Epoch 179/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1600 - accuracy: 0.0137 - binary_accuracy: 0.7565 - val_loss: 0.1817 - val_accuracy: 0.0107 - val_binary_accuracy: 0.7162
# Epoch 180/500
# 35/35 [==============================] - 3s 83ms/step - loss: 0.1600 - accuracy: 0.0130 - binary_accuracy: 0.7565 - val_loss: 0.1817 - val_accuracy: 0.0164 - val_binary_accuracy: 0.7164
# Epoch 181/500
# 35/35 [==============================] - 3s 78ms/step - loss: 0.1599 - accuracy: 0.0138 - binary_accuracy: 0.7566 - val_loss: 0.1817 - val_accuracy: 0.0115 - val_binary_accuracy: 0.7161
# Epoch 182/500
# 35/35 [==============================] - 3s 81ms/step - loss: 0.1599 - accuracy: 0.0133 - binary_accuracy: 0.7566 - val_loss: 0.1817 - val_accuracy: 0.0108 - val_binary_accuracy: 0.7159
# Epoch 183/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1599 - accuracy: 0.0133 - binary_accuracy: 0.7567 - val_loss: 0.1819 - val_accuracy: 0.0123 - val_binary_accuracy: 0.7151
# Epoch 184/500
# 35/35 [==============================] - 3s 78ms/step - loss: 0.1599 - accuracy: 0.0123 - binary_accuracy: 0.7567 - val_loss: 0.1818 - val_accuracy: 0.0144 - val_binary_accuracy: 0.7154
# Epoch 185/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1599 - accuracy: 0.0135 - binary_accuracy: 0.7567 - val_loss: 0.1817 - val_accuracy: 0.0099 - val_binary_accuracy: 0.7165
# Epoch 186/500
# 35/35 [==============================] - 3s 80ms/step - loss: 0.1598 - accuracy: 0.0135 - binary_accuracy: 0.7568 - val_loss: 0.1820 - val_accuracy: 0.0084 - val_binary_accuracy: 0.7152
# Epoch 187/500
# 35/35 [==============================] - 3s 81ms/step - loss: 0.1598 - accuracy: 0.0130 - binary_accuracy: 0.7568 - val_loss: 0.1822 - val_accuracy: 0.0117 - val_binary_accuracy: 0.7153
# Epoch 188/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1599 - accuracy: 0.0132 - binary_accuracy: 0.7567 - val_loss: 0.1818 - val_accuracy: 0.0171 - val_binary_accuracy: 0.7162
# Epoch 189/500
# 35/35 [==============================] - 3s 83ms/step - loss: 0.1598 - accuracy: 0.0138 - binary_accuracy: 0.7569 - val_loss: 0.1820 - val_accuracy: 0.0110 - val_binary_accuracy: 0.7157
# Epoch 190/500
# 35/35 [==============================] - 3s 78ms/step - loss: 0.1598 - accuracy: 0.0128 - binary_accuracy: 0.7568 - val_loss: 0.1820 - val_accuracy: 0.0125 - val_binary_accuracy: 0.7153
# Epoch 191/500
# 35/35 [==============================] - 3s 81ms/step - loss: 0.1598 - accuracy: 0.0133 - binary_accuracy: 0.7569 - val_loss: 0.1822 - val_accuracy: 0.0147 - val_binary_accuracy: 0.7153
# Epoch 192/500
# 35/35 [==============================] - 3s 80ms/step - loss: 0.1597 - accuracy: 0.0136 - binary_accuracy: 0.7569 - val_loss: 0.1820 - val_accuracy: 0.0088 - val_binary_accuracy: 0.7158
# Epoch 193/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1598 - accuracy: 0.0123 - binary_accuracy: 0.7569 - val_loss: 0.1819 - val_accuracy: 0.0126 - val_binary_accuracy: 0.7159
# Epoch 194/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1598 - accuracy: 0.0131 - binary_accuracy: 0.7570 - val_loss: 0.1823 - val_accuracy: 0.0119 - val_binary_accuracy: 0.7149
# Epoch 195/500
# 35/35 [==============================] - 3s 78ms/step - loss: 0.1598 - accuracy: 0.0138 - binary_accuracy: 0.7570 - val_loss: 0.1821 - val_accuracy: 0.0158 - val_binary_accuracy: 0.7154
# Epoch 196/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1597 - accuracy: 0.0139 - binary_accuracy: 0.7570 - val_loss: 0.1820 - val_accuracy: 0.0174 - val_binary_accuracy: 0.7158
# Epoch 197/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1596 - accuracy: 0.0143 - binary_accuracy: 0.7572 - val_loss: 0.1822 - val_accuracy: 0.0077 - val_binary_accuracy: 0.7147
# Epoch 198/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1596 - accuracy: 0.0129 - binary_accuracy: 0.7572 - val_loss: 0.1820 - val_accuracy: 0.0127 - val_binary_accuracy: 0.7162
# Epoch 199/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1596 - accuracy: 0.0136 - binary_accuracy: 0.7573 - val_loss: 0.1823 - val_accuracy: 0.0116 - val_binary_accuracy: 0.7158
# Epoch 200/500
# 35/35 [==============================] - 3s 81ms/step - loss: 0.1597 - accuracy: 0.0131 - binary_accuracy: 0.7571 - val_loss: 0.1823 - val_accuracy: 0.0123 - val_binary_accuracy: 0.7150
# Epoch 201/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1596 - accuracy: 0.0134 - binary_accuracy: 0.7572 - val_loss: 0.1822 - val_accuracy: 0.0071 - val_binary_accuracy: 0.7151
# Epoch 202/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1596 - accuracy: 0.0129 - binary_accuracy: 0.7573 - val_loss: 0.1823 - val_accuracy: 0.0088 - val_binary_accuracy: 0.7155
# Epoch 203/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1596 - accuracy: 0.0128 - binary_accuracy: 0.7573 - val_loss: 0.1822 - val_accuracy: 0.0107 - val_binary_accuracy: 0.7150
# Epoch 204/500
# 35/35 [==============================] - 3s 83ms/step - loss: 0.1595 - accuracy: 0.0129 - binary_accuracy: 0.7574 - val_loss: 0.1823 - val_accuracy: 0.0108 - val_binary_accuracy: 0.7148
# Epoch 205/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1595 - accuracy: 0.0133 - binary_accuracy: 0.7574 - val_loss: 0.1825 - val_accuracy: 0.0156 - val_binary_accuracy: 0.7142
# Epoch 206/500
# 35/35 [==============================] - 3s 81ms/step - loss: 0.1596 - accuracy: 0.0135 - binary_accuracy: 0.7573 - val_loss: 0.1824 - val_accuracy: 0.0126 - val_binary_accuracy: 0.7150
# Epoch 207/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1596 - accuracy: 0.0128 - binary_accuracy: 0.7573 - val_loss: 0.1826 - val_accuracy: 0.0147 - val_binary_accuracy: 0.7146
# Epoch 208/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1595 - accuracy: 0.0132 - binary_accuracy: 0.7574 - val_loss: 0.1826 - val_accuracy: 0.0129 - val_binary_accuracy: 0.7148
# Epoch 209/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1595 - accuracy: 0.0131 - binary_accuracy: 0.7575 - val_loss: 0.1825 - val_accuracy: 0.0109 - val_binary_accuracy: 0.7147
# Epoch 210/500
# 35/35 [==============================] - 3s 83ms/step - loss: 0.1595 - accuracy: 0.0124 - binary_accuracy: 0.7576 - val_loss: 0.1825 - val_accuracy: 0.0120 - val_binary_accuracy: 0.7148
# Epoch 211/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1595 - accuracy: 0.0130 - binary_accuracy: 0.7575 - val_loss: 0.1826 - val_accuracy: 0.0085 - val_binary_accuracy: 0.7145
# Epoch 212/500
# 35/35 [==============================] - 3s 81ms/step - loss: 0.1595 - accuracy: 0.0125 - binary_accuracy: 0.7575 - val_loss: 0.1825 - val_accuracy: 0.0176 - val_binary_accuracy: 0.7154
# Epoch 213/500
# 35/35 [==============================] - 3s 78ms/step - loss: 0.1594 - accuracy: 0.0131 - binary_accuracy: 0.7576 - val_loss: 0.1827 - val_accuracy: 0.0146 - val_binary_accuracy: 0.7144
# Epoch 214/500
# 35/35 [==============================] - 3s 83ms/step - loss: 0.1594 - accuracy: 0.0132 - binary_accuracy: 0.7577 - val_loss: 0.1825 - val_accuracy: 0.0120 - val_binary_accuracy: 0.7157
# Epoch 215/500
# 35/35 [==============================] - 3s 78ms/step - loss: 0.1594 - accuracy: 0.0131 - binary_accuracy: 0.7577 - val_loss: 0.1826 - val_accuracy: 0.0166 - val_binary_accuracy: 0.7141
# Epoch 216/500
# 35/35 [==============================] - 3s 81ms/step - loss: 0.1594 - accuracy: 0.0138 - binary_accuracy: 0.7577 - val_loss: 0.1824 - val_accuracy: 0.0089 - val_binary_accuracy: 0.7157
# Epoch 217/500
# 35/35 [==============================] - 3s 80ms/step - loss: 0.1593 - accuracy: 0.0123 - binary_accuracy: 0.7578 - val_loss: 0.1826 - val_accuracy: 0.0094 - val_binary_accuracy: 0.7150
# Epoch 218/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1594 - accuracy: 0.0131 - binary_accuracy: 0.7577 - val_loss: 0.1826 - val_accuracy: 0.0113 - val_binary_accuracy: 0.7146
# Epoch 219/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1593 - accuracy: 0.0126 - binary_accuracy: 0.7578 - val_loss: 0.1827 - val_accuracy: 0.0102 - val_binary_accuracy: 0.7143
# Epoch 220/500
# 35/35 [==============================] - 3s 83ms/step - loss: 0.1593 - accuracy: 0.0123 - binary_accuracy: 0.7579 - val_loss: 0.1826 - val_accuracy: 0.0198 - val_binary_accuracy: 0.7149
# Epoch 221/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1593 - accuracy: 0.0139 - binary_accuracy: 0.7578 - val_loss: 0.1828 - val_accuracy: 0.0113 - val_binary_accuracy: 0.7146
# Epoch 222/500
# 35/35 [==============================] - 3s 81ms/step - loss: 0.1593 - accuracy: 0.0131 - binary_accuracy: 0.7579 - val_loss: 0.1829 - val_accuracy: 0.0156 - val_binary_accuracy: 0.7138
# Epoch 223/500
# 35/35 [==============================] - 3s 80ms/step - loss: 0.1593 - accuracy: 0.0123 - binary_accuracy: 0.7579 - val_loss: 0.1827 - val_accuracy: 0.0114 - val_binary_accuracy: 0.7145
# Epoch 224/500
# 35/35 [==============================] - 3s 81ms/step - loss: 0.1593 - accuracy: 0.0129 - binary_accuracy: 0.7579 - val_loss: 0.1828 - val_accuracy: 0.0147 - val_binary_accuracy: 0.7143
# Epoch 225/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1593 - accuracy: 0.0129 - binary_accuracy: 0.7580 - val_loss: 0.1827 - val_accuracy: 0.0109 - val_binary_accuracy: 0.7148
# Epoch 226/500
# 35/35 [==============================] - 3s 81ms/step - loss: 0.1593 - accuracy: 0.0129 - binary_accuracy: 0.7580 - val_loss: 0.1832 - val_accuracy: 0.0078 - val_binary_accuracy: 0.7139
# Epoch 227/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1593 - accuracy: 0.0130 - binary_accuracy: 0.7578 - val_loss: 0.1830 - val_accuracy: 0.0087 - val_binary_accuracy: 0.7135
# Epoch 228/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1593 - accuracy: 0.0124 - binary_accuracy: 0.7579 - val_loss: 0.1827 - val_accuracy: 0.0103 - val_binary_accuracy: 0.7149
# Epoch 229/500
# 35/35 [==============================] - 3s 78ms/step - loss: 0.1592 - accuracy: 0.0129 - binary_accuracy: 0.7580 - val_loss: 0.1829 - val_accuracy: 0.0099 - val_binary_accuracy: 0.7147
# Epoch 230/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1592 - accuracy: 0.0127 - binary_accuracy: 0.7580 - val_loss: 0.1828 - val_accuracy: 0.0080 - val_binary_accuracy: 0.7139
# Epoch 231/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1592 - accuracy: 0.0137 - binary_accuracy: 0.7582 - val_loss: 0.1828 - val_accuracy: 0.0106 - val_binary_accuracy: 0.7151
# Epoch 232/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1592 - accuracy: 0.0132 - binary_accuracy: 0.7581 - val_loss: 0.1829 - val_accuracy: 0.0127 - val_binary_accuracy: 0.7137
# Epoch 233/500
# 35/35 [==============================] - 3s 78ms/step - loss: 0.1592 - accuracy: 0.0129 - binary_accuracy: 0.7581 - val_loss: 0.1828 - val_accuracy: 0.0135 - val_binary_accuracy: 0.7150
# Epoch 234/500
# 35/35 [==============================] - 3s 81ms/step - loss: 0.1592 - accuracy: 0.0129 - binary_accuracy: 0.7582 - val_loss: 0.1831 - val_accuracy: 0.0144 - val_binary_accuracy: 0.7134
# Epoch 235/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1591 - accuracy: 0.0134 - binary_accuracy: 0.7582 - val_loss: 0.1830 - val_accuracy: 0.0123 - val_binary_accuracy: 0.7143
# Epoch 236/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1592 - accuracy: 0.0137 - binary_accuracy: 0.7581 - val_loss: 0.1831 - val_accuracy: 0.0181 - val_binary_accuracy: 0.7138
# Epoch 237/500
# 35/35 [==============================] - 3s 81ms/step - loss: 0.1591 - accuracy: 0.0128 - binary_accuracy: 0.7582 - val_loss: 0.1829 - val_accuracy: 0.0101 - val_binary_accuracy: 0.7147
# Epoch 238/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1591 - accuracy: 0.0126 - binary_accuracy: 0.7584 - val_loss: 0.1829 - val_accuracy: 0.0156 - val_binary_accuracy: 0.7144
# Epoch 239/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1591 - accuracy: 0.0130 - binary_accuracy: 0.7584 - val_loss: 0.1832 - val_accuracy: 0.0095 - val_binary_accuracy: 0.7137
# Epoch 240/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1591 - accuracy: 0.0123 - binary_accuracy: 0.7581 - val_loss: 0.1832 - val_accuracy: 0.0098 - val_binary_accuracy: 0.7140
# Epoch 241/500
# ...
# Epoch 421/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1577 - accuracy: 0.0122 - binary_accuracy: 0.7611 - val_loss: 0.1854 - val_accuracy: 0.0086 - val_binary_accuracy: 0.7104
# Epoch 422/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1577 - accuracy: 0.0121 - binary_accuracy: 0.7611 - val_loss: 0.1853 - val_accuracy: 0.0105 - val_binary_accuracy: 0.7108
# Epoch 423/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1577 - accuracy: 0.0121 - binary_accuracy: 0.7611 - val_loss: 0.1856 - val_accuracy: 0.0138 - val_binary_accuracy: 0.7100
# Epoch 424/500
# 35/35 [==============================] - 3s 80ms/step - loss: 0.1577 - accuracy: 0.0125 - binary_accuracy: 0.7612 - val_loss: 0.1853 - val_accuracy: 0.0101 - val_binary_accuracy: 0.7108
# Epoch 425/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1577 - accuracy: 0.0118 - binary_accuracy: 0.7612 - val_loss: 0.1853 - val_accuracy: 0.0103 - val_binary_accuracy: 0.7110
# Epoch 426/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1576 - accuracy: 0.0125 - binary_accuracy: 0.7613 - val_loss: 0.1852 - val_accuracy: 0.0107 - val_binary_accuracy: 0.7109
# Epoch 427/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1577 - accuracy: 0.0121 - binary_accuracy: 0.7613 - val_loss: 0.1855 - val_accuracy: 0.0129 - val_binary_accuracy: 0.7108
# Epoch 428/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1577 - accuracy: 0.0117 - binary_accuracy: 0.7612 - val_loss: 0.1857 - val_accuracy: 0.0164 - val_binary_accuracy: 0.7096
# Epoch 429/500
# 35/35 [==============================] - 3s 83ms/step - loss: 0.1577 - accuracy: 0.0121 - binary_accuracy: 0.7613 - val_loss: 0.1856 - val_accuracy: 0.0109 - val_binary_accuracy: 0.7096
# Epoch 430/500
# 35/35 [==============================] - 3s 78ms/step - loss: 0.1577 - accuracy: 0.0120 - binary_accuracy: 0.7612 - val_loss: 0.1853 - val_accuracy: 0.0098 - val_binary_accuracy: 0.7110
# Epoch 431/500
# 35/35 [==============================] - 3s 80ms/step - loss: 0.1576 - accuracy: 0.0120 - binary_accuracy: 0.7613 - val_loss: 0.1852 - val_accuracy: 0.0118 - val_binary_accuracy: 0.7114
# Epoch 432/500
# 35/35 [==============================] - 3s 81ms/step - loss: 0.1577 - accuracy: 0.0121 - binary_accuracy: 0.7613 - val_loss: 0.1854 - val_accuracy: 0.0128 - val_binary_accuracy: 0.7107
# Epoch 433/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1577 - accuracy: 0.0128 - binary_accuracy: 0.7612 - val_loss: 0.1853 - val_accuracy: 0.0129 - val_binary_accuracy: 0.7112
# Epoch 434/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1578 - accuracy: 0.0121 - binary_accuracy: 0.7611 - val_loss: 0.1854 - val_accuracy: 0.0095 - val_binary_accuracy: 0.7107
# Epoch 435/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1576 - accuracy: 0.0127 - binary_accuracy: 0.7614 - val_loss: 0.1854 - val_accuracy: 0.0094 - val_binary_accuracy: 0.7104
# Epoch 436/500
# 35/35 [==============================] - 3s 83ms/step - loss: 0.1576 - accuracy: 0.0124 - binary_accuracy: 0.7614 - val_loss: 0.1857 - val_accuracy: 0.0119 - val_binary_accuracy: 0.7087
# Epoch 437/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1576 - accuracy: 0.0120 - binary_accuracy: 0.7614 - val_loss: 0.1855 - val_accuracy: 0.0100 - val_binary_accuracy: 0.7103
# Epoch 438/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1576 - accuracy: 0.0116 - binary_accuracy: 0.7613 - val_loss: 0.1857 - val_accuracy: 0.0119 - val_binary_accuracy: 0.7103
# Epoch 439/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1577 - accuracy: 0.0121 - binary_accuracy: 0.7612 - val_loss: 0.1855 - val_accuracy: 0.0108 - val_binary_accuracy: 0.7100
# Epoch 440/500
# 35/35 [==============================] - 3s 83ms/step - loss: 0.1576 - accuracy: 0.0121 - binary_accuracy: 0.7613 - val_loss: 0.1858 - val_accuracy: 0.0132 - val_binary_accuracy: 0.7089
# Epoch 441/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1576 - accuracy: 0.0120 - binary_accuracy: 0.7613 - val_loss: 0.1857 - val_accuracy: 0.0164 - val_binary_accuracy: 0.7098
# Epoch 442/500
# 35/35 [==============================] - 3s 83ms/step - loss: 0.1577 - accuracy: 0.0120 - binary_accuracy: 0.7613 - val_loss: 0.1855 - val_accuracy: 0.0170 - val_binary_accuracy: 0.7102
# Epoch 443/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1576 - accuracy: 0.0123 - binary_accuracy: 0.7614 - val_loss: 0.1856 - val_accuracy: 0.0120 - val_binary_accuracy: 0.7096
# Epoch 444/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1576 - accuracy: 0.0123 - binary_accuracy: 0.7614 - val_loss: 0.1856 - val_accuracy: 0.0116 - val_binary_accuracy: 0.7098
# Epoch 445/500
# 35/35 [==============================] - 3s 80ms/step - loss: 0.1576 - accuracy: 0.0121 - binary_accuracy: 0.7614 - val_loss: 0.1854 - val_accuracy: 0.0123 - val_binary_accuracy: 0.7107
# Epoch 446/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1576 - accuracy: 0.0119 - binary_accuracy: 0.7614 - val_loss: 0.1857 - val_accuracy: 0.0130 - val_binary_accuracy: 0.7102
# Epoch 447/500
# 35/35 [==============================] - 3s 81ms/step - loss: 0.1576 - accuracy: 0.0123 - binary_accuracy: 0.7613 - val_loss: 0.1855 - val_accuracy: 0.0117 - val_binary_accuracy: 0.7103
# Epoch 448/500
# 35/35 [==============================] - 3s 83ms/step - loss: 0.1576 - accuracy: 0.0120 - binary_accuracy: 0.7615 - val_loss: 0.1855 - val_accuracy: 0.0096 - val_binary_accuracy: 0.7102
# Epoch 449/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1575 - accuracy: 0.0121 - binary_accuracy: 0.7616 - val_loss: 0.1860 - val_accuracy: 0.0126 - val_binary_accuracy: 0.7090
# Epoch 450/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1576 - accuracy: 0.0121 - binary_accuracy: 0.7613 - val_loss: 0.1857 - val_accuracy: 0.0162 - val_binary_accuracy: 0.7095
# Epoch 451/500
# 35/35 [==============================] - 3s 84ms/step - loss: 0.1576 - accuracy: 0.0123 - binary_accuracy: 0.7614 - val_loss: 0.1855 - val_accuracy: 0.0172 - val_binary_accuracy: 0.7103
# Epoch 452/500
# 35/35 [==============================] - 3s 86ms/step - loss: 0.1575 - accuracy: 0.0133 - binary_accuracy: 0.7615 - val_loss: 0.1857 - val_accuracy: 0.0123 - val_binary_accuracy: 0.7105
# Epoch 453/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1576 - accuracy: 0.0122 - binary_accuracy: 0.7615 - val_loss: 0.1857 - val_accuracy: 0.0087 - val_binary_accuracy: 0.7102
# Epoch 454/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1576 - accuracy: 0.0121 - binary_accuracy: 0.7614 - val_loss: 0.1857 - val_accuracy: 0.0118 - val_binary_accuracy: 0.7097
# Epoch 455/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1575 - accuracy: 0.0123 - binary_accuracy: 0.7616 - val_loss: 0.1857 - val_accuracy: 0.0171 - val_binary_accuracy: 0.7101
# Epoch 456/500
# 35/35 [==============================] - 3s 83ms/step - loss: 0.1575 - accuracy: 0.0123 - binary_accuracy: 0.7615 - val_loss: 0.1855 - val_accuracy: 0.0104 - val_binary_accuracy: 0.7103
# Epoch 457/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1576 - accuracy: 0.0119 - binary_accuracy: 0.7614 - val_loss: 0.1860 - val_accuracy: 0.0099 - val_binary_accuracy: 0.7094
# Epoch 458/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1576 - accuracy: 0.0119 - binary_accuracy: 0.7614 - val_loss: 0.1854 - val_accuracy: 0.0117 - val_binary_accuracy: 0.7110
# Epoch 459/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1575 - accuracy: 0.0126 - binary_accuracy: 0.7615 - val_loss: 0.1859 - val_accuracy: 0.0123 - val_binary_accuracy: 0.7097
# Epoch 460/500
# 35/35 [==============================] - 3s 84ms/step - loss: 0.1576 - accuracy: 0.0122 - binary_accuracy: 0.7614 - val_loss: 0.1860 - val_accuracy: 0.0113 - val_binary_accuracy: 0.7090
# Epoch 461/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1576 - accuracy: 0.0122 - binary_accuracy: 0.7615 - val_loss: 0.1857 - val_accuracy: 0.0120 - val_binary_accuracy: 0.7100
# Epoch 462/500
# 35/35 [==============================] - 3s 78ms/step - loss: 0.1575 - accuracy: 0.0122 - binary_accuracy: 0.7616 - val_loss: 0.1857 - val_accuracy: 0.0094 - val_binary_accuracy: 0.7101
# Epoch 463/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1575 - accuracy: 0.0131 - binary_accuracy: 0.7615 - val_loss: 0.1858 - val_accuracy: 0.0175 - val_binary_accuracy: 0.7103
# Epoch 464/500
# 35/35 [==============================] - 3s 83ms/step - loss: 0.1575 - accuracy: 0.0128 - binary_accuracy: 0.7615 - val_loss: 0.1860 - val_accuracy: 0.0126 - val_binary_accuracy: 0.7093
# Epoch 465/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1576 - accuracy: 0.0123 - binary_accuracy: 0.7615 - val_loss: 0.1859 - val_accuracy: 0.0095 - val_binary_accuracy: 0.7095
# Epoch 466/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1576 - accuracy: 0.0121 - binary_accuracy: 0.7614 - val_loss: 0.1856 - val_accuracy: 0.0114 - val_binary_accuracy: 0.7104
# Epoch 467/500
# 35/35 [==============================] - 3s 83ms/step - loss: 0.1575 - accuracy: 0.0122 - binary_accuracy: 0.7617 - val_loss: 0.1860 - val_accuracy: 0.0124 - val_binary_accuracy: 0.7082
# Epoch 468/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1575 - accuracy: 0.0122 - binary_accuracy: 0.7617 - val_loss: 0.1857 - val_accuracy: 0.0107 - val_binary_accuracy: 0.7096
# Epoch 469/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1575 - accuracy: 0.0121 - binary_accuracy: 0.7616 - val_loss: 0.1859 - val_accuracy: 0.0133 - val_binary_accuracy: 0.7098
# Epoch 470/500
# 35/35 [==============================] - 3s 83ms/step - loss: 0.1575 - accuracy: 0.0124 - binary_accuracy: 0.7615 - val_loss: 0.1857 - val_accuracy: 0.0108 - val_binary_accuracy: 0.7103
# Epoch 471/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1576 - accuracy: 0.0122 - binary_accuracy: 0.7615 - val_loss: 0.1860 - val_accuracy: 0.0135 - val_binary_accuracy: 0.7087
# Epoch 472/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1575 - accuracy: 0.0123 - binary_accuracy: 0.7615 - val_loss: 0.1858 - val_accuracy: 0.0125 - val_binary_accuracy: 0.7098
# Epoch 473/500
# 35/35 [==============================] - 3s 81ms/step - loss: 0.1574 - accuracy: 0.0125 - binary_accuracy: 0.7617 - val_loss: 0.1857 - val_accuracy: 0.0099 - val_binary_accuracy: 0.7101
# Epoch 474/500
# 35/35 [==============================] - 3s 83ms/step - loss: 0.1575 - accuracy: 0.0124 - binary_accuracy: 0.7617 - val_loss: 0.1856 - val_accuracy: 0.0124 - val_binary_accuracy: 0.7104
# Epoch 475/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1574 - accuracy: 0.0125 - binary_accuracy: 0.7618 - val_loss: 0.1859 - val_accuracy: 0.0121 - val_binary_accuracy: 0.7098
# Epoch 476/500
# 35/35 [==============================] - 3s 81ms/step - loss: 0.1575 - accuracy: 0.0123 - binary_accuracy: 0.7617 - val_loss: 0.1856 - val_accuracy: 0.0108 - val_binary_accuracy: 0.7107
# Epoch 477/500
# 35/35 [==============================] - 3s 84ms/step - loss: 0.1575 - accuracy: 0.0126 - binary_accuracy: 0.7617 - val_loss: 0.1859 - val_accuracy: 0.0096 - val_binary_accuracy: 0.7096
# Epoch 478/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1574 - accuracy: 0.0125 - binary_accuracy: 0.7617 - val_loss: 0.1859 - val_accuracy: 0.0137 - val_binary_accuracy: 0.7093
# Epoch 479/500
# 35/35 [==============================] - 3s 81ms/step - loss: 0.1575 - accuracy: 0.0125 - binary_accuracy: 0.7617 - val_loss: 0.1861 - val_accuracy: 0.0121 - val_binary_accuracy: 0.7087
# Epoch 480/500
# 35/35 [==============================] - 3s 83ms/step - loss: 0.1575 - accuracy: 0.0124 - binary_accuracy: 0.7617 - val_loss: 0.1857 - val_accuracy: 0.0097 - val_binary_accuracy: 0.7109
# Epoch 481/500
# 35/35 [==============================] - 3s 81ms/step - loss: 0.1575 - accuracy: 0.0122 - binary_accuracy: 0.7617 - val_loss: 0.1859 - val_accuracy: 0.0140 - val_binary_accuracy: 0.7092
# Epoch 482/500
# 35/35 [==============================] - 3s 81ms/step - loss: 0.1575 - accuracy: 0.0124 - binary_accuracy: 0.7616 - val_loss: 0.1859 - val_accuracy: 0.0106 - val_binary_accuracy: 0.7088
# Epoch 483/500
# 35/35 [==============================] - 3s 80ms/step - loss: 0.1575 - accuracy: 0.0123 - binary_accuracy: 0.7617 - val_loss: 0.1860 - val_accuracy: 0.0122 - val_binary_accuracy: 0.7093
# Epoch 484/500
# 35/35 [==============================] - 3s 80ms/step - loss: 0.1574 - accuracy: 0.0121 - binary_accuracy: 0.7617 - val_loss: 0.1857 - val_accuracy: 0.0129 - val_binary_accuracy: 0.7110
# Epoch 485/500
# 35/35 [==============================] - 3s 81ms/step - loss: 0.1574 - accuracy: 0.0130 - binary_accuracy: 0.7617 - val_loss: 0.1856 - val_accuracy: 0.0128 - val_binary_accuracy: 0.7109
# Epoch 486/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1574 - accuracy: 0.0122 - binary_accuracy: 0.7618 - val_loss: 0.1859 - val_accuracy: 0.0110 - val_binary_accuracy: 0.7102
# Epoch 487/500
# 35/35 [==============================] - 3s 81ms/step - loss: 0.1575 - accuracy: 0.0121 - binary_accuracy: 0.7616 - val_loss: 0.1860 - val_accuracy: 0.0120 - val_binary_accuracy: 0.7097
# Epoch 488/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1575 - accuracy: 0.0123 - binary_accuracy: 0.7616 - val_loss: 0.1859 - val_accuracy: 0.0110 - val_binary_accuracy: 0.7103
# Epoch 489/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1574 - accuracy: 0.0123 - binary_accuracy: 0.7617 - val_loss: 0.1860 - val_accuracy: 0.0092 - val_binary_accuracy: 0.7091
# Epoch 490/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1574 - accuracy: 0.0126 - binary_accuracy: 0.7620 - val_loss: 0.1860 - val_accuracy: 0.0130 - val_binary_accuracy: 0.7095
# Epoch 491/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1573 - accuracy: 0.0123 - binary_accuracy: 0.7620 - val_loss: 0.1861 - val_accuracy: 0.0154 - val_binary_accuracy: 0.7089
# Epoch 492/500
# 35/35 [==============================] - 3s 81ms/step - loss: 0.1574 - accuracy: 0.0122 - binary_accuracy: 0.7619 - val_loss: 0.1857 - val_accuracy: 0.0124 - val_binary_accuracy: 0.7101
# Epoch 493/500
# 35/35 [==============================] - 3s 83ms/step - loss: 0.1573 - accuracy: 0.0130 - binary_accuracy: 0.7620 - val_loss: 0.1858 - val_accuracy: 0.0094 - val_binary_accuracy: 0.7103
# Epoch 494/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1574 - accuracy: 0.0121 - binary_accuracy: 0.7618 - val_loss: 0.1860 - val_accuracy: 0.0152 - val_binary_accuracy: 0.7095
# Epoch 495/500
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1574 - accuracy: 0.0126 - binary_accuracy: 0.7617 - val_loss: 0.1860 - val_accuracy: 0.0137 - val_binary_accuracy: 0.7095
# Epoch 496/500
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1574 - accuracy: 0.0127 - binary_accuracy: 0.7619 - val_loss: 0.1861 - val_accuracy: 0.0120 - val_binary_accuracy: 0.7092
# Epoch 497/500
# 35/35 [==============================] - 3s 80ms/step - loss: 0.1574 - accuracy: 0.0125 - binary_accuracy: 0.7619 - val_loss: 0.1862 - val_accuracy: 0.0120 - val_binary_accuracy: 0.7094
# Epoch 498/500
# 35/35 [==============================] - 3s 83ms/step - loss: 0.1574 - accuracy: 0.0123 - binary_accuracy: 0.7618 - val_loss: 0.1859 - val_accuracy: 0.0110 - val_binary_accuracy: 0.7100
# Epoch 499/500
# 35/35 [==============================] - 3s 81ms/step - loss: 0.1574 - accuracy: 0.0129 - binary_accuracy: 0.7617 - val_loss: 0.1861 - val_accuracy: 0.0147 - val_binary_accuracy: 0.7087
# Epoch 500/500
# 35/35 [==============================] - 3s 81ms/step - loss: 0.1573 - accuracy: 0.0125 - binary_accuracy: 0.7620 - val_loss: 0.1863 - val_accuracy: 0.0118 - val_binary_accuracy: 0.7086

# %%
print("Loss: {}".format(history.history['loss']))
print("Validation Loss: {}".format(history.history['val_loss']))
print("Validation Accuracy: {}".format(history.history['val_accuracy']))
# Out:
# Loss: [0.17835503816604614, 0.17191094160079956, 0.1715185046195984, 0.17138563096523285, 0.17129413783550262, 0.1712343841791153, 0.17116862535476685, 0.17110799252986908, 0.17104437947273254, 0.1709853708744049, 0.17092542350292206, 0.17085878551006317, 0.1707763373851776, 0.17069244384765625, 0.1706109493970871, 0.17053823173046112, 0.1704282909631729, 0.17033255100250244, 0.17022258043289185, 0.17011727392673492, 0.17000745236873627, 0.16989445686340332, 0.16977965831756592, 0.169644296169281, 0.16951817274093628, 0.16938146948814392, 0.16925641894340515, 0.16911514103412628, 0.16897818446159363, 0.16886913776397705, 0.16869136691093445, 0.16859444975852966, 0.16844305396080017, 0.16830983757972717, 0.16817842423915863, 0.16804607212543488, 0.1679316759109497, 0.1677711009979248, 0.16765011847019196, 0.16751159727573395, 0.1673957109451294, 0.16725893318653107, 0.16717064380645752, 0.16703304648399353, 0.16687709093093872, 0.16676048934459686, 0.16663573682308197, 0.16649454832077026, 0.16639664769172668, 0.16626068949699402, 0.1661739945411682, 0.16606183350086212, 0.16595147550106049, 0.16580693423748016, 0.16570593416690826, 0.16560639441013336, 0.16550695896148682, 0.16538529098033905, 0.16530676186084747, 0.16519547998905182, 0.16510145366191864, 0.1649911105632782, 0.16490013897418976, 0.1647980958223343, 0.16473540663719177, 0.16461290419101715, 0.16454088687896729, 0.1644681692123413, 0.1643463671207428, 0.1642625778913498, 0.16420318186283112, 0.16410291194915771, 0.16402947902679443, 0.16395975649356842, 0.1638680398464203, 0.16378900408744812, 0.16372214257717133, 0.16366951167583466, 0.16363902390003204, 0.16354738175868988, 0.16345471143722534, 0.16337060928344727, 0.16331170499324799, 0.1632409393787384, 0.16316905617713928, 0.16311576962471008, 0.1630726456642151, 0.16301794350147247, 0.16294489800930023, 0.16294817626476288, 0.16284312307834625, 0.1627628058195114, 0.16274625062942505, 0.16268083453178406, 0.16260989010334015, 0.1625596135854721, 0.16250447928905487, 0.16242879629135132, 0.16243432462215424, 0.1623547524213791, 0.1623082309961319, 0.1622680425643921, 0.16223053634166718, 0.16220040619373322, 0.162135511636734, 0.16207166016101837, 0.16208286583423615, 0.16204392910003662, 0.16192848980426788, 0.1619112342596054, 0.16187825798988342, 0.1618211567401886, 0.16183406114578247, 0.1617623120546341, 0.1617918610572815, 0.16167350113391876, 0.16165883839130402, 0.16158755123615265, 0.16155286133289337, 0.16153737902641296, 0.16149300336837769, 0.16145800054073334, 0.1614355742931366, 0.16137386858463287, 0.16131150722503662, 0.16131724417209625, 0.16125579178333282, 0.1612437516450882, 0.16123029589653015, 0.16121762990951538, 0.16115537285804749, 0.16114355623722076, 0.1611180603504181, 0.16111090779304504, 0.16113285720348358, 0.16096612811088562, 0.1609955132007599, 0.16093340516090393, 0.16096195578575134, 0.1609196662902832, 0.16087429225444794, 0.1608651727437973, 0.16084730625152588, 0.16075868904590607, 0.16074641048908234, 0.160730242729187, 0.16070197522640228, 0.16065196692943573, 0.1606728434562683, 0.16063696146011353, 0.16060076653957367, 0.16058267652988434, 0.16055262088775635, 0.16051481664180756, 0.16051262617111206, 0.16046029329299927, 0.16040964424610138, 0.16047681868076324, 0.16043917834758759, 0.16038700938224792, 0.16038201749324799, 0.16036231815814972, 0.16034932434558868, 0.16029362380504608, 0.16023960709571838, 0.16025038063526154, 0.16022345423698425, 0.16023197770118713, 0.16018709540367126, 0.16014514863491058, 0.1601686328649521, 0.16012927889823914, 0.16009151935577393, 0.16009585559368134, 0.1601005494594574, 0.16009916365146637, 0.1600017547607422, 0.15996673703193665, 0.15999864041805267, 0.15998436510562897, 0.15993784368038177, 0.1599217802286148, 0.15988092124462128, 0.15989357233047485, 0.15986241400241852, 0.15984857082366943, 0.15983326733112335, 0.15989652276039124, 0.1598096638917923, 0.15981711447238922, 0.15979290008544922, 0.15974865853786469, 0.1597 ...
# Validation Loss: [0.17139728367328644, 0.1709470897912979, 0.17074033617973328, 0.17071393132209778, 0.17071962356567383, 0.1707214117050171, 0.1706881821155548, 0.17068998515605927, 0.17071810364723206, 0.1707233041524887, 0.17072224617004395, 0.17069853842258453, 0.17072661221027374, 0.17079925537109375, 0.17080137133598328, 0.1708112210035324, 0.1708311140537262, 0.17086422443389893, 0.17094948887825012, 0.1710074245929718, 0.1710398942232132, 0.17115344107151031, 0.17121416330337524, 0.17129617929458618, 0.17134332656860352, 0.1714315563440323, 0.17151731252670288, 0.17163404822349548, 0.17173698544502258, 0.17181697487831116, 0.17195004224777222, 0.172037273645401, 0.1721898764371872, 0.17222139239311218, 0.1723715215921402, 0.17251378297805786, 0.172603577375412, 0.17268720269203186, 0.1728447824716568, 0.17298297584056854, 0.17307649552822113, 0.17320223152637482, 0.17332704365253448, 0.17338082194328308, 0.17363660037517548, 0.17359696328639984, 0.1737135499715805, 0.17392702400684357, 0.17399699985980988, 0.17409850656986237, 0.17420846223831177, 0.17440859973430634, 0.17441152036190033, 0.17460176348686218, 0.17463195323944092, 0.1747979372739792, 0.1748349368572235, 0.17496894299983978, 0.17512668669223785, 0.1752631664276123, 0.17533428966999054, 0.17542047798633575, 0.17552942037582397, 0.1755269467830658, 0.17567190527915955, 0.1758372187614441, 0.1758730411529541, 0.17596827447414398, 0.17602306604385376, 0.1761401891708374, 0.17616179585456848, 0.17634977400302887, 0.1764880120754242, 0.1766147017478943, 0.1766311377286911, 0.1766776591539383, 0.17681393027305603, 0.17694790661334991, 0.17707546055316925, 0.1770169883966446, 0.17705711722373962, 0.17718295753002167, 0.17717409133911133, 0.17723454535007477, 0.17731691896915436, 0.1775146722793579, 0.17772740125656128, 0.17761030793190002, 0.17781737446784973, 0.17786607146263123, 0.17770904302597046, 0.17800742387771606, 0.17796997725963593, 0.178009495139122, 0.17806224524974823, 0.1781156212091446, 0.1781919300556183, 0.1782592236995697, 0.17828989028930664, 0.17835260927677155, 0.17863351106643677, 0.17864911258220673, 0.17857478559017181, 0.17871339619159698, 0.17859883606433868, 0.178731769323349, 0.17897871136665344, 0.17868193984031677, 0.1791088581085205, 0.17914347350597382, 0.17891427874565125, 0.17927080392837524, 0.1790381819009781, 0.17938077449798584, 0.1793726086616516, 0.17936664819717407, 0.17923249304294586, 0.17929375171661377, 0.17931391298770905, 0.17956656217575073, 0.17957288026809692, 0.17964479327201843, 0.17949730157852173, 0.17953960597515106, 0.17965707182884216, 0.17955820262432098, 0.17982210218906403, 0.1799195408821106, 0.17992441356182098, 0.17982517182826996, 0.17997455596923828, 0.1801830679178238, 0.1801881194114685, 0.1803618222475052, 0.18004509806632996, 0.180392324924469, 0.18032509088516235, 0.18013891577720642, 0.18034203350543976, 0.18032677471637726, 0.18045388162136078, 0.18073618412017822, 0.1805771291255951, 0.1804880052804947, 0.18036071956157684, 0.18067330121994019, 0.18046627938747406, 0.18062347173690796, 0.1807120442390442, 0.18093067407608032, 0.18095612525939941, 0.18076469004154205, 0.18089134991168976, 0.18087759613990784, 0.1809585988521576, 0.1809093952178955, 0.18101391196250916, 0.18104617297649384, 0.18120644986629486, 0.1810438483953476, 0.1812606304883957, 0.18114697933197021, 0.18128684163093567, 0.1811324805021286, 0.18135051429271698, 0.18127621710300446, 0.18123124539852142, 0.18131816387176514, 0.18131065368652344, 0.18137094378471375, 0.18137571215629578, 0.18137910962104797, 0.18141920864582062, 0.18151092529296875, 0.18159618973731995, 0.18160293996334076, 0.1814412921667099, 0.18177443742752075, 0.18169629573822021, 0.181665301322937, 0.1817266345024109, 0.1817215234041214, 0.1819392591714859, 0.1818307340145111, 0.18167923390865326, 0.18202215433120728, 0.18218813836574554, 0.1817929446697235, 0.18199925124645233, 0.18200884759426117, 0.18216219544410706, 0.18200024962425232, 0.1819059848 ...
# Validation Accuracy: [0.005064092576503754, 0.00010550192382652313, 0.00337606156244874, 0.013029487803578377, 0.019095849245786667, 0.007596138399094343, 0.018884845077991486, 0.012607480399310589, 0.005011341534554958, 0.013662499375641346, 0.008703908883035183, 0.0104974415153265, 0.015719786286354065, 0.012818483635783195, 0.012660231441259384, 0.014506515115499496, 0.015192276798188686, 0.012712981551885605, 0.007068628910928965, 0.0035870654974132776, 0.007068628910928965, 0.014770269393920898, 0.010128185153007507, 0.014506515115499496, 0.016247296705842018, 0.008281901478767395, 0.013715250417590141, 0.010339188389480114, 0.010075434111058712, 0.010972199961543083, 0.011605211533606052, 0.018884845077991486, 0.010550192557275295, 0.010444690473377705, 0.010444690473377705, 0.005591602064669132, 0.0167220551520586, 0.009600675664842129, 0.010550192557275295, 0.008281901478767395, 0.011816215701401234, 0.00902041420340538, 0.009231418371200562, 0.013451495207846165, 0.0076488894410431385, 0.00833465252071619, 0.009073165245354176, 0.02257741242647171, 0.013451495207846165, 0.010708445683121681, 0.011921717785298824, 0.015034024603664875, 0.011024951003491879, 0.013979004696011543, 0.014770269393920898, 0.00749063678085804, 0.01434826198965311, 0.0167220551520586, 0.015245027840137482, 0.013662499375641346, 0.01978161185979843, 0.014875771477818489, 0.015034024603664875, 0.013768001459538937, 0.015139526687562466, 0.01060294359922409, 0.011024951003491879, 0.009389671497046947, 0.00712137995287776, 0.013556997291743755, 0.023210423067212105, 0.02110038511455059, 0.0127657325938344, 0.012185472063720226, 0.01339874416589737, 0.010708445683121681, 0.016089044511318207, 0.014664767310023308, 0.01661655306816101, 0.0164583008736372, 0.0167220551520586, 0.01134145725518465, 0.0104974415153265, 0.015878040343523026, 0.018884845077991486, 0.012027219869196415, 0.013029487803578377, 0.010022683069109917, 0.017566069960594177, 0.012976736761629581, 0.011077702045440674, 0.011868966743350029, 0.015245027840137482, 0.00965342577546835, 0.01039193943142891, 0.014506515115499496, 0.015772538259625435, 0.017618821933865547, 0.005697104148566723, 0.013662499375641346, 0.010075434111058712, 0.02241915836930275, 0.008651157841086388, 0.01777707412838936, 0.015139526687562466, 0.013451495207846165, 0.012343725189566612, 0.0104974415153265, 0.0226829145103693, 0.021627895534038544, 0.014084506779909134, 0.014823020435869694, 0.011552460491657257, 0.015930790454149246, 0.012976736761629581, 0.013082238845527172, 0.018357334658503532, 0.016141794621944427, 0.013293243013322353, 0.015456032007932663, 0.013979004696011543, 0.01967610977590084, 0.010339188389480114, 0.017302315682172775, 0.008651157841086388, 0.008123648352921009, 0.01508677564561367, 0.016247296705842018, 0.013134989887475967, 0.012027219869196415, 0.01113045308738947, 0.014770269393920898, 0.012554729357361794, 0.010128185153007507, 0.015614285133779049, 0.013134989887475967, 0.00902041420340538, 0.01039193943142891, 0.01640554890036583, 0.013662499375641346, 0.00833465252071619, 0.010550192557275295, 0.020625626668334007, 0.014823020435869694, 0.012396476231515408, 0.011552460491657257, 0.018568338826298714, 0.02236640825867653, 0.022049902006983757, 0.013556997291743755, 0.010866697877645493, 0.011499709449708462, 0.009336920455098152, 0.008123648352921009, 0.012923985719680786, 0.01039193943142891, 0.01060294359922409, 0.011499709449708462, 0.012607480399310589, 0.010866697877645493, 0.012818483635783195, 0.0104974415153265, 0.008070897310972214, 0.006910376250743866, 0.009917180985212326, 0.013873503543436527, 0.01339874416589737, 0.0127657325938344, 0.011394208297133446, 0.010708445683121681, 0.013240491971373558, 0.017513319849967957, 0.010655694641172886, 0.014717518351972103, 0.010972199961543083, 0.01957060769200325, 0.012449227273464203, 0.016827557235956192, 0.010708445683121681, 0.01640554890036583, 0.011499709449708462, 0.010761196725070477, 0.012343725189566612,  ...

# %% [markdown]
# ### Testing
# Here, we evaluate the neural network with the test data.
#
# This block stays the same.

# %% [markdown]
# ### Prediction
# Here is where we use the network as an attack. We could skip the testing phase and use this as our own testing phase. Here we could add the text correction "layer" and calculate the actual score we want, maybe using binary accuracy probability as a metric.

# %%
results = neural_network.evaluate(test_samples, test_labels, batch_size=batch_size)
print("Test loss: {}".format(results[0]))
print("Test accuracy: {}".format(results[1]))
# Out:
# 17/17 [==============================] - 0s 26ms/step - loss: 0.1868 - accuracy: 0.0127 - binary_accuracy: 0.7068
# Test loss: 0.1868186742067337
# Test accuracy: 0.012702632695436478

# %%
pred_size = 1000
predictions = [predict_sample(neural_network, test_samples[i]) for i in range(pred_size)]
# Out:
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step

# %%
metrics = [correct_and_metrics((predictions[i], test_labels[i])) for i in range(pred_size)]

# %%
correct_bytes = 0
correct_predictions = 0
for m in metrics:
    correct_bytes += m[0]
    correct_predictions += m[1]
num_bytes = len(test_labels[0]) // 8
                             
print("Correct bytes: {}".format(correct_bytes))
print("Byte accuracy: {}".format(correct_bytes/(num_bytes*pred_size)))
print("Correct predictions: {}".format(correct_predictions))
print("Prediction accuracy: {}".format(correct_predictions/pred_size))
# Out:
# Correct bytes: 752
# Byte accuracy: 0.047
# Correct predictions: 0
# Prediction accuracy: 0.0

# %%
for i in range(pred_size):
    print(prediction_to_string(test_labels[i]) + " || " + prediction_to_string(predictions[i]))
# Out:
# :33 And when thi || he u`dd mm `jar`
# s cometh to pass || d``jd g(v aed`en
# , (lo, it will c || fd hed``dd`e`a`e
# ome,) then shall || `d```aee adiv ao
#
# they know that  || d```e`daad```ab`
# a prophet hath b || de(u(uhe``a`u`d`
# een among them.
#  || b```d`e```ae`ahe
#
# 34:1 And the wo || d`aohen``md dhe`
# rd of the LORD c || ` `le `md``ae`eb
# ame unto me, say || ad fd `md d(ap``
# ing, 34:2 Son of || `ab` ao  `o$ bme
#  man,
# prophesy a ||  mo00ae``mb`e``d
# gainst the sheph || `ddd`a`e`aamn```
# erds of Israel,  ||  dl`d`ge``he` ej
# prophesy, and sa || `eld`omd``eb``he
# y unto them,
# Thu || !on$ die``m`amh`
# s saith the Lord || `o`a`daed`iod  `
#  GOD unto the sh || amd`ad`ehdd`od `
# epherds; Woe be  || `ejd `eg  aed ``
# to the shepherds || hm$`oc``hd`ed``m
#  of
# Israel that  || `d` aed``aedddd`
# do feed themselv || (nl `l0 aed`hmd`
# es! should not t || aee`de `edd`gm``
# he shepherds fee || ``e``ag```oa`h``
# d the
# flocks?  3 || elpbd`d``a`aeddd
# 4:3 Ye eat the f ||  mne `e u(emf` e
# at, and ye cloth || d``ed `he dao` h
# e you with the w || be`f``e``e`aod u
# ool, ye kill
# the || al`dj``od p`e``d
# m that are fed:  || d`h`d `ie``dd`ah
# but ye feed not  || h` `hdbe`d`e`aef
# the flock.
#
# 34:4 || `e `amd `oef(e`a
#  The diseased ha || al `e` d`e``agd`
# ve ye not streng || d``le ah```ad ae
# thened, neither  || `pal`edd``e` hld
# have ye healed
# t || ee`dho `he``g` e
# hat which was si || e```h````ad```e`
# ck, neither have || ```ag edd``e```a
#  ye bound up tha || `a`dd``d`da``eed
# t which was brok || `f p`ee`e`d```ha
# en,
# neither have || di aol `m`d `o``
#  ye brought agai || la``t ul``gd`de`
# n that which was ||  `ie```ied``de `
#  driven away, ne || afd``e` `mo$ je
# ither have
# ye so || ``hedd````d`med`
# ught that which  || d`a`d``d`ed``o`d
# was lost; but wi || he`add``le`gd dh
# th force and wit || `imd `md`e"`md `
# h cruelty have y || io  i`d`d`d`d`d`
# e
# ruled them.
#
# 3 || ld `le```ad``le`
# 4:5 And they wer || `df`ddm``dhqnd w
# e scattered, bec || dlg`a`ag `ed`b`i
# ause there is no || ge`aodd`dd`aed`d
#  shepherd: and t || edd```d`he``md `
# hey
# became meat  || `feddeg``pe`e``h
# to all the beast || `a`ap`e d`gd`aod
# s of the field,  || ``in bmiw poe  e
# when they were s || `ab`d`af aod`e e
# cattered.
#
# 34:6  || a`e```e` hg the`
# My sheep wandere || a`ad`ehdd `if `l
# d through all th || `ohe dkf$ e`d`de
# e mountains, and || og `ifb```ddhd`a
#  upon every high || dg dh``l`  emd``
#
# hill: yea, my f || `d`dd``ed`a``e``
# lock was scatter || ll `le```eo`````
# ed upon all the  ||  `in ``e dhav ao
# face of the eart || ``ea`d`al` aag`
# h, and
# none did  || d(``dd`e`ed`eh``
# search or seek a || mg `ll`hd(e eb `
# fter them.
#
# 34:7 || an``fedld`k```a`
#  Therefore, ye s || al```of`d`e`f `h
# hepherds, hear t || m``led`in ``eg`a
# he word of the L || a``id `ae``cmd `
# ORD; 34:8 As I
# l || d`ebd`dd``aa`d o
# ive, saith the L || `d`eh amadh`he`d
# ord GOD, surely  || ``m`d``ad`eed`m`
# because my flock ||  `ad ``ed`f`e``o
#  became a prey,  || `ae``m`dhg` did`
# and
# my flock bec || d``e`dmn !od `hd
# ame meat to ever || md` cgd`hd`aat a
# y beast of the f || ap``ed`hed```eda
# ield, because th || dld hod ``ad`a`e
# ere was no
# sheph || bebbd bd pheh`th
# erd, neither did || je `h difd aiu`
#  my shepherds se || en`kl  wfd`ald`h
# arch for my floc || `d`md pio  cn```
# k, but the
# sheph || l`ed uh aa`dhe`
# erds fed themsel ||  `aod``le`v`ag f
# ves, and fed not || d`ead dm`ll``abe
#  my flock; 34:9  || d`ad``o``dae e`e
# Therefore, O ye
#  || d `je `aodd`od`a
# shepherds, hear  || add`d`eht`w eld`
# the word of the  || `if `id ``phdd`d
# LORD; 34:10 Thus || lh`hm dht en `bg
#  saith the Lord  || `m`f```ade`d`dje
# GOD;
# Behold, I a || `d`e`eil`d ul  a
# m against the sh || e`dhed `mmd ao `
# epherds; and I w || ```amd god`m`` e
# ill require my f || ee  ad```d`edd d
# lock at
# their ha || `e t u`d`dd bcq
# nd, and cause th ||  me` d`ae``al``a
# em to cease from || ` on  o t``d`dlg
#  feeding the flo || `m``he````e`ded`
# ck; neither
# shal || e `o``l`ehgn``da
# l the shepherds  || `m``bd ``e````e`
# feed themselves  || dd``dd e`d aod `
# any more; for I  || daed agd``e`ah`d
# will deliver my
#  || `e`ed`ehdha``d`d
# flock from their || e`agl``o ` aod`l
#  mouth, that the || ``ae`ehm```gf  e
# y may not be mea || hd`og `h```eht`e
# t for them.
#
# 34: || `l` `d``hd`dd`aj
# 11 For thus sait || aed av`dje``had`
# h the Lord GOD;  ||  a`d``e`ad`d```e
# Behold, I, even  || `ed bn``g `me ``
# I, will both sea || `e``id `l```ea``
# rch
# my sheep, an || d```aeh`ae `ded`
# d seek them out. || m`f`dd`ed`aeg `i
#
#
# 34:12 As a she || `ehe`naf` a``ld`
# pherd seeketh ou ||  d`d``d`d `m````
# t his flock in t || ``ald`e``e e`a``
# he day that he i || `md `eld`hahd``m
# s among
# his shee || (eh``hg``mdep`mb
# p that are scatt ||  mhd`aiaf`ehadd`
# ered; so will I  || `d`amd hoe  ent
# seek out my shee || ``"`jd``d$dh`d`e
# p, and will
# deli || `dae``dld e`d``e
# ver them out of  || `g th `ie `lfd a
# all places where || ``df`f`ag``jebb`
#  they have been  || f```dbfd`dbeled`
# scattered in the ||  lmd `af `m`d`fd
#
# cloudy and dark || `d`d `au``eldeh`
#  day.
#
# 34:13 And || al  mmd`ae`dhe``
#  I will bring th || c``ahd`ae``med d
# em out from the  || `a`ed `id``he``h
# people, and gath || `ed`ded```e```ae
# er them from
# the || dl`paed``eae```e
#  countries, and  || `d`e`ddhe`d gm`
# will bring them  || ll `acg phed``be
# to their own lan || `aeedd`cg pa`md`
# d, and feed them || `el dhee`edfdd`e
#
# upon the mounta ||  `jg dhod ahe eh
# ins of Israel by || ah``f```e` dea`a
#  the rivers, and || d `ddd die``md``
#  in all the inha || ```w``d`eddd`ehd
# bited
# places of  ||  `awna`ke  kla a
# the country.
#
# 34 || ed`mb`he``ae`d e
# :14 I will feed  || `e`d`a`aw```e`d
# them in a good p || `on  lr `d`gd `
# asture, and upon || debl`an```eadd`h
#  the high mounta || ho  baw dhdll"q`
# ins
# of Israel sh || `he``dddd`daeh`w
# all their fold b ||  `if ``al pie```
# e: there shall t || `amd `me `af``h`
# hey lie in a goo || de`dhb`a`l`dd```
# d fold,
# and in a || `e``h`addded`e e
#  fat pasture sha || `dig``die `io  o
# ll they feed upo || ad`end `oe0 m`dh
# n the mountains  || `d`d`od`````dd`d
# of Israel.
#
# 34:1 || d`eh bh``````ela
# 5 I will feed my || ```aed `ce eod `
#  flock, and I wi ||  tjc``acg  ioe0a
# ll cause them to || e `mjd `o` ag```
#  lie down, saith || `e`e`en``iw 0ie
#
# the Lord GOD.
#
#  || fd tdp$ al`a`e`e
# 34:16 I will see || `eb`je `idd`m``l
# k that which was || f`f`e  oe` ``e``
#  lost, and bring || `e`f` ao` Niw ``
#  again that whic || d``f`bedde`f`d`a
# h was
# driven awa || ae$`hejd hmd0@mn
# y, and will bind ||  `of bhw @n d`d`
#  up that which w || `e``hdhdh`amd``e
# as broken, and w || d`````phd`ed`ed
# ill
# strengthen t || bh`vaav e`d``gbd
# hat which was si || e``m` ``g` emd``
# ck: but I will d || hd`o `k`p(q``a`d
# estroy the fat a || `mdlebeh` p`d`he
# nd the
# strong; I || ````d``dd whdjf
#  will feed them  || `e`dd `aed eldd
# with judgment.
#
#  || d`d e` aied``cda
# 34:17 And as for || ``ald `mo png ``
#  you, O my flock || d``hef `of ````a
# , thus saith the || d``je `mje ao``n
#  Lord GOD; Behol || l`ej`e`t`dh`d dh
# d, I
# judge betwe || heh`a`dah`ede`d`
# en cattle and ca || dd`d`gdd `dee ``
# ttle, between th || `o` ahed `go 0he
# e rams and the h || nd`eld`d``d``a`e
# e goats.
#
# 34:18  || d```hm`e`md`the`
# Seemeth it a sma || `anp n `md `o``
# ll thing unto yo || daod uod hahd`pe
# u to have eaten  || p ````na`ma amd
# up the good
# past || t`e``ed`m```m``h
# ure, but ye must || e``dbu `h`a`ehdh
#  tread down with || `eed`fe``e``oa``
#  your feet the r || dm"ehd``l e```pl
# esidue of your
# p ||  (d sna`ed eid`
# astures? and to  || `d``end`he`d``e`
# have drunk of th ||  `md0`gd```a~ `l
# e deep waters, b || (g(t w``h``e``d`
# ut ye must foul  || e``nd ag```mdd`a
# the
# residue with || `e``md```de dld`
#  your feet?  34: || ````eh``t`d`dl``
# 19 And as for my || `ed``hmd``ce`ebd
#  flock, they eat || `gd```e u`e`ee`d
#  that
# which ye h || `hdd`aa``ed``ed`
# ave trodden with || `elt eit`aed`dkd
#  your feet; and  || d``gabe`d u uhe
# they drink that  || had``dd`dd`d`a``
# which ye
# have fo || f``of `ehehd``da
# uled with your f || ``add@d`ehe`aid`
# eet.
#
# 34:20 Ther || dd`dd`de`e`ae`d`
# efore thus saith || ```aev``md fhd `
#  the Lord GOD un || ia``cn aad` `de`
# to them; Behold, || `g`d`e``ehe ab``
#  I, even I,
# will || `de`ne aof `odd
#  judge between t || `d e`ad``d``e$`d
# he fat cattle an ||  `am `e`d`ea`ehe
# d between the le || ae`eg``lg ``ehpm
# an cattle.
#
# 34:2 || `hg`p`eo `a``had
# 1 Because ye hav || `e`d`de`e`eidhdd
# e thrust with si || ed a``md `mmdpao
# de and with shou || aed`ede em pjke`
# lder, and pushed || ``dded`eod`bm``r
#
# all the disease || daif de```aadd d
# d with your horn || d`e``qa phed`eb`
# s, till ye have  || d`en``eabf efd a
# scattered them a || ad `mhfa`ajd``d`
# broad;
# 34:22 The || na``md`ehe`e`e`d
# refore will I sa || `d`f`eld`md`bf`a
# ve my flock, and ||   jg  ` `eh`ae`d
#  they shall no m || ehd`el pho` ehe`
# ore be a
# prey; a || ``hwh``he``efdef
# nd I will judge  || p``og aa`d`dfehd
# between cattle a || ``a``udd``dhe``q
# nd cattle.
#
# 34:2 || bgdaed em```m``d
# 3 And I will set || d aol `me  kg  a
#  up one shepherd || `e`aoe dmd```ao
#  over them, and  || emd `md `aod aoe
# he shall feed
# th || `g  `dd ed ald``
# em, even my serv || dd`u(d`d`dhame``
# ant David; he sh || `d```e``f`d e``e
# all feed them, a || `dddadd``be ed e
# nd he shall be t || `e```efp`ede`hi`
# heir
# shepherd.
#
#  || `u paed ele  m``
# 34:24 And I the  || d`(iof ``d`p`aed
# LORD will be the || he kgld`hd eh`ah
# ir God, and my s || cf `le tig  oo$
# ervant David a p || heav e`e a`ml eb
# rince
# among them || ` ge`d` e`a``ehd
# ; I the LORD hav || d`ae`a`de`dd`a``
# e spoken it.
#
# 34 || de`e`w`he akd `o
# :25 And I will m || `eddf`mo$ co dhe
# ake with them a  || ``ind `mb `edp m
# covenant of peac || e`dedg"`o` dhu``
# e, and will caus || ``ejd`a```anl `m
# e
# the evil beast || `ae`d`ao abed``e
# s to cease out o || d` e`uhad ejt`he
# f the land: and  || `ke`dd(fb `d`d`d
# they shall dwell || he`add`e```and e
#  safely
# in the w || `a``e``dld`edadd
# ilderness, and s || hg `hd`de edd```
# leep in the wood || md``nd dif``of e
# s.
#
# 34:26 And I  || `ed`eh``ilf uif
# will make them a || ``ald`hdad```e a
# nd the places ro || ag ``ded```ea` b
# und about my hil || a`e`l``l``f`d`ee
# l a
# blessing; an || hd(a`ed`e`d ae`
# d I will cause t || `ej` t`e ``a```e
# he shower to com || `ji`````dd``edd`
# e down in his se || `md ao$ rmd `ig`
# ason;
# there shal || `je `f`al` ie``e
# l be showers of  || `e u`f `hap``am`
# blessing.
#
# 34:27 || ``md `od `mn `oe
#  And the tree of || a`e`a``ed``im`d`
#  the field shall || `u"e`en `hebd``a
#  yield her fruit || afgdad`a````e` `
# , and the earth
#  || d`aod `m````ehd`
# shall yield her  || dd``aed``o` ``d`
# increase, and th || `e``mv co  `l`p`
# ey shall be safe || e`d`e```d`d`d`a`
#  in their land,  || d```w`dae`aed`gd
# and
# shall know t || `igd`l`e`dd dhd`
# hat I am the LOR || eb`cld `mt ah` a
# D, when I have b || ``m`d`d`ed`ahad`
# roken the bands  || ifd`hdelf  aif
# of their
# yoke, a ||  d``d ahd``d``e`
# nd delivered the || `ag `oe` ie w` e
# m out of the han || ld``e`dacad  ``e
# d of those that  || `ie``aed``ae `jf
# served
# themselve || `ed``ad``ed``lde
# s of them.
#
# 34:2 || eld ce dhdhgd am
# 8 And they shall || `m` oid`ue`ame `
#  no more be a pr || `e``he` `oe``e`a
# ey to the heathe || ad`d`eh``aa``hd
# n, neither shall || ig po` `ae```o`e
#
# the beast of th || `mh``````ie``cm
# e land devour th || ae  p`mf`gbamd``
# em; but they sha || d``e`d``e`e`hed`
# ll dwell safely, || `dd`ed`ahebbohd`
#  and
# none shall  || d `cd```de```e``
# make them afraid || daen``e`fm`d`ed`
# .
#
# 34:29 And I w || `g```kg  lf eld
# ill raise up for || `ehbd`e`ad `me e
#  them a plant of || `````e`ahed``e`e
#  renown, and the ||  t(ebl``le``ad`a
# y shall
# be no mo || `md ahf g````ed`
# re consumed with || ``m``dd`ed and`e
#  hunger in the l || d p```d`aled`d`e
# and, neither bea || `g`pmedd`an abaq
# r the shame of
# t || agn hld se`phe``
# he heathen any m || `hdabe``d ahda`e
# ore.
#
# 34:30 Thus || `a`nd d`e`e``acd
#  shall they know || di``ed`at ddd```
#  that I the LORD || `e`ajmd `mu ded`
#  their God am wi || ``d``o` eoe `g`t
# th them, and
# tha || `d`e(dha`he t sg
# t they, even the || `e`d`of gmd`md e
#  house of Israel || e`dldt`ebd`ad ``
# , are my people, ||  md  aoe eod```a
#  saith the Lord
#  ||  dhwd waa`pa`mda
# GOD.
#
# 34:31 And  || `e`e`ml`e``ad`af
# ye my flock, the || `t``e`d```fm ``e
#  flock of my pas || d dhd``e````ud h
# ture, are men, a || ```m``kod gjef a
# nd I am your
# God || `ao$ amd `aae``e
# , saith the Lord || `e`f `oi` ead`d`
#  GOD.
#
# 35:1 More || aene rh`d Aed ac
# over the word of || `l`d`agd dmd`eld
#  the LORD came u || d`jd`ehd`behd` o
# nto me, saying,  || dd``aehgd ``fd e
# 35:2 Son of
# man, || hg hmd did eo `i
#  set thy face ag || `a`d`e`e`d``cd a
# ainst mount Seir || d emed``md p`e`h
# , and prophesy a || a`a`ad`e`adddf`a
# gainst it, 35:3
#  || d`adldje a`d ``i
# And say unto it, || tbd il ````ed`a`
#  Thus saith the  || `u `mdd go  a``h
# Lord GOD; Behold || an`v`ap e``add`g
# , O mount Seir,  || e`ad qhe`ae```de
# I am
# against the || hd`ed `mm  mo`dl
# e, and I will st || eld`hebd ee`d gh
# retch out mine h || `f`d`qd`addd`ad`
# and against thee || am 0`eed ong  `a
# , and I
# will mak || ``eld@d an pad `
# e thee most deso || `f`gd`ed`ind``lf
# late.
#
# 35:4 I wi || dd``hg`c`ha`h``d
# ll lay thy citie || `l`dh`m``ld`l```
# s waste, and tho || `mf` ehdd ead``a
# u shalt be desol || d`d eod` emd```e
# ate, and thou
# sh || `edhep`ae``ke `e
# alt know that I  || lea``jd`wl``ld h
# am the LORD.
#
# 35 || l rf `mn `napee`
# :5 Because thou  || `````d`a```he ``
# hast had a perpe || ld``d``uhd`ad `e
# tual hatred, and || j``he`g qhc` at`
#  hast shed the b || d``nhphed``ie`d`
# lood
# of the chil || `ol`daehd`aehd`f
# dren of Israel b || ``fdebd``e akm$
# y the force of t || `acd `md dh`d`d`
# he sword in the  || `e`ejgd ehdhd pn
# time of
# their ca || `ad`e`mh`d`ee `e
# lamity, in the t || dd`go``iehed``ej
# ime that their i || `n ``e``ame af`d
# niquity had an e || je``hf  pie``e(u
# nd: 35:6
# Therefo || ```e``hm` ehq``e
# re, as I live, s || ce`ejd jmd``o``g
# aith the Lord GO || `m` `afd``g` ``a
# D, I will prepar || dd``d`e`d`ebd b`
# e thee unto
# bloo || `amb`adad`age ``
# d, and blood sha || ``d`add`d`bap``e
# ll pursue thee:  || `d``dad`nm` `e``
# sith thou hast n ||  ehu ``od ehq``h
# ot hated blood,
#  || f  ``dd aad`ddd`
# even blood shall || d`dmdd``dd`dig
#  pursue thee.
#
# 3 || `dhehe ea`d``ada
# 5:7 Thus will I  || e`e``ed`l```dida
# make mount Seir  ||  `aedd`edht`ehd
# most desolate, a || `jd `a`dd$`eaq`e
# nd cut off from  || hdcf ``q`aad``jd
# it
# him that pass || ``dd`ed`amd`el `
# eth out and him  || dhebd``e`ddl`ud`
# that returneth.
#  || `e "uh`dd``gd` a
#
# 35:8 And I will || `l ed`e`e```g``a
#  fill his mounta || ``e`a`old`ke `me
# ins with his sla || e``d```md``eed`e
# in men: in thy h || `dde `me  iod0 p
# ills,
# and in thy || e 0 gm `he````ad
#  valleys, and in || d``o qhua eied `
#  all thy rivers, || of `mn `eae``l`o
#  shall they fall || `` gie `ied`aa``
#  that are
# slain  || d``aed mm`dhd`fa
# with the sword.
#  || ad``ad`e`d`de`de
#
# 35:9 I will mak || `ig``di```gkd`ef
# e thee perpetual || `e`ce``ad aod d`
#  desolations, an || `e`dle`e`g``die
# d thy cities sha || `g`````dae`ed`b`
# ll not
# return: a || `e`aped depoe `h
# nd ye shall know || `ekp me`d`ude``e
#  that I am the L || ae``lm$``i```d
# ORD.
#
# 35:10 Beca || he eldd a`eab``o
# use thou hast sa || da``ehd```ddc`dl
# id, These two na || dav aldd```ae`ae
# tions and these  || d`hhd`d``eb`g`d`
# two
# countries sh || `m`dbdd``me ehde
# all be mine, and || m``lhea```eld`dd
#  we will possess || hg````ead`ed `if
#  it; whereas the || emdd`ald e`d`ee`
#  LORD was
# there: || `e` an`u`e``ddd`
#  35:11 Therefore || dd`a`dddhd`ad``a
# , as I live, sai ||  wi``pm `dfd`a`
# th the Lord GOD, || e` eld`aw `l`e``
#  I will even do
#  || `dir ud``bd`gd``
# according to thi || ed je` a`````e``
# ne anger, and ac || ```ed``d`t```ed`
# cording to thine || `ldhdn`t ag``d`e
#  envy which thou || `afdd`aied m`d `
#  hast
# used out o || ``aha d`am  hfd`
# f thy hatred aga || ``abu gh`dhe ``g
# inst them; and I ||  ae``al```gd`d`e
#  will make mysel || ddld``ao dld hd
# f known
# among th ||  `kt `g`` `u`a``
# em, when I have  ||  div``a`t a`ea `
# judged thee.
#
# 35 || `````eu ehd`o``a
# :12 And thou sha || `e``hu dm`u gape
# lt know that I a || hd `n ``adde`dd`
# m the LORD, and  || ej``ed ``od``mh`
# that I have hear || `d`md`aml  dd d
# d
# all thy blasph || he e`dadel``dl`d
# emies which thou || af `n`phg `e` ``
#  hast spoken aga || adhe`d`ed``od am
# inst the mountai || fd `ct ee```gh``
# ns of
# Israel, sa || d`ae```m```mf `m
# ying, They are l || ``aw `m``he`ahda
# aid desolate, th || hee``n`d`ed`abe`
# ey are given us  || a``dlb`hd`a`de`d
# to consume.
#
# 35: || `e tid `md$`od q
# 13 Thus with you || `e`d`aea``e`e `e
# r mouth ye have  || dn`````paed``od`
# boasted against  || hd phe`daa``ed``
# me, and have
# mul || `andfh`qwd`io q
# tiplied your wor || eef``mm ``nm```g
# ds against me: I || dh`befd``lj```d`
#  have heard them || hg `d dhel `hgd`
# .
#
# 35:14 Thus sa || mldhl,`dkt alf``
# ith the Lord GOD ||  `id `eld`me`a`a
# ; When the whole || `al d`ad`aqdde`d
#  earth rejoiceth || e`eid dhg `h```e
# , I will
# make th || e` aod`  pnd``e
# ee desolate.
#
# 35 || ` en phd`u``eedm
# :15 As thou dids || mo$ iae``add`ied
# t rejoice at the ||  eaddio$ `g`t`ae
#  inheritance of  || dd`biedtha` ejv(
# the house of Isr || `ee``jn, hu ae`d
# ael,
# because it  || ae eob `id``mdd
# was desolate, so || ee `ie l`v e`u`a
#  will I do unto  ||  a`be`el`a`a`d e
# thee: thou shalt || d`e`d `ifd dhe``
#  be
# desolate, O  || p`af``mf  e`dd`a
# mount Seir, and  || ```ed ao```md`ea
# all Idumea, even || e`edhd``dme`daan
#  all of it: and  || md Piw` d eof!pm
# they shall
# know  || h` wd phd`ad`gha
# that I am the LO || `nnd i` eb``au s
# RD.
#
# 36:1 Also,  || aa`d`eb`g g(dr`p
# thou son of man, || af `hf  am``h``a
#  prophesy unto t || `edd``e`e`aifdp`
# he mountains of  || dhabed`add```eda
# Israel, and
# say, || `ah`dho  gd```eh
#  Ye mountains of || `ecdhatha`aelee`
#  Israel, hear th ||  ef``hnd `mod ad
# e word of the LO ||  `aed eaddddm``g
# RD: 36:2 Thus
# sa || dd``dd`ag` dae(e
# ith the Lord GOD || on  mg` ``ed qhe
# ; Because the en ||  l`e`eo``ho  qh`
# emy hath said ag || ```e`dhe`da`de`d
# ainst you, Aha,  || `an$ el  d`ed``a
# even
# the ancient || m` a`t``m a`ee`d
#  high places are || ``d` amd mlde`u`
#  ours in possess || d aid `e`al`dhd`
# ion: 36:3 Theref || e`d`daddgd amu e
# ore
# prophesy and || `d`edd`od aod io
#  say, Thus saith || hd pd`d`eh`l`ae`
#  the Lord GOD; B || e`l````ed`p`el`d
# ecause they have || ` au`a`ke pl` `e
#  made you
# desola || `o``t`e``l``he d
# te, and swallowe || ```ad``eed`me ae
# d you up on ever || `mf eod  add wi`
# y side, that ye  || d`he`d``e`dhe``a
# might be a
# posse || dh`d`f `e````ed`
# ssion unto the r || di`ld`e```en`a`o
# esidue of the he || hdabe`dl```ee``i
# athen, and ye ar || ad`e ghd aedd`e`
# e taken up in th || dd`ke `af`dapd`e
# e
# lips of talker || `ae``he``ae`  `m
# s, and are an in || aol `dd w `mht m
# famy of the peop || ad```ddd`end aig
# le: 36:4 Therefo ||  en``v`eed`````a
# re, ye
# mountains || e `ed`dhe`````d`
#  of Israel, hear || `elddct qid `ae`
#  the word of the || hd q`d``d ``ge e
#  Lord GOD; Thus  ||  vhp e`e``ao`e`d
# saith the
# Lord G || o`ehce`qddd`e``m
# OD to the mounta || `m`e(d`an `e `he
# ins, and to the  || `m dhel`a``amd `
# hills, to the ri || `g`dh `og `gdd o
# vers, and to the || `e``end`e``da`a`
#
# valleys, to the || d`add`dd``eld o`
#  desolate wastes || `d``ld ric aaad`
# , and to the cit || ejd kg `ld``ajd`
# ies that are for || ``eda`m```gl``hg
# saken,
# which bec || ie ``dn ujdhll a
# ame a prey and d || `md ehe `e`d`e`d
# erision to the r || aed``bav(ul  ie
# esidue of the he || ``e`d``e`ahdd`d`
# athen that
# are r || dd!q`ao dnd```d`
# ound about; 36:5 || deg``jd e`e dh`d
#  Therefore thus  || `agd``ke `ie ``e
# saith the Lord G || d`dae d``d`ae``m
# OD; Surely in th || `od e``d`eb ```a
# e
# fire of my jea || `e`alb ``ea`d``g
# lousy have I spo || ae`d e`f`abaghd`
# ken against the  || ed bm  gh `ae` a
# residue of the h || e`edd om  *wd ``
# eathen,
# and agai || `d`ehf ae`d`e`d`
# nst all Idumea,  || `e`dd``e`t`aedd`
# which have appoi || `w"`av ``djd ``a
# nted my land int ||  ``e``ed`ame``id
# o their
# possessi || e `he````ed`a`e`
# on with the joy  || md do``ead`h````
# of all their hea ||  ao ``ne eladfdb
# rt, with despite || `oo$ uh`d uhdd e
# ful minds, to
# ca || b`behd ao```ad `
# st it out for a  || dd ahd`da`ed`e``
# prey.
#
# 36:6 Prop || an`ad`fl  ll ehe
# hesy therefore c || ``e`afd````eddaf
# oncerning the la || `eld`ad`uhd`cdd`
# nd of Israel, an || ``ef `of `mat`eo
# d say unto
# the m || dm dje``am``dd`d
# ountains, and to || al``aed e`ed```e
#  the hills, to t || al```d``i`a`f` u
# he rivers, and t || d``eddh`id `ml$h
# o the valleys,
# T || aed`add`me`dhd c
# hus saith the Lo || dbe  ehu ddau `d
# rd GOD; Behold,  || af `d````ebee` h
# I have spoken in || a`hehu `hnd `ce`
#  my jealousy and || `a``d`ehd `m`d e
#  in
# my fury, bec || `eddd`a``e``ecd`
# ause ye have bor ||  bcdd````la`omd
# ne the shame of  || hd ded `aedhend`
# the heathen: 36: || `abed`l`e a aed`
# 7
# Therefore thus || `de````mn `ilb `
#  saith the Lord  ||  `add fe`t``e go
# GOD; I have lift || e``hmg hae```oaa
# ed up mine hand, || `danda`p`afe`dh`
#  Surely
# the heat || `dbod ``w```agh`
# hen that are abo ||  `b`pe`edd`ed```
# ut you, they sha || `ehd ed`e aiad e
# ll bear their sh || `d`ed `ad``ddal`
# ame.
#
# 36:8 But y || de dae` `md`agd
# e, O mountains o || ad aln ``` eae`e
# f Israel, ye sha || hmb `ld `hej`d``
# ll shoot forth y || `add`dl``e`agl a
# our
# branches, an || bee`aoe `nda`e``
# d yield your fru || el`e`dad`af ded`
# it to my people  || d`e$ `od eag uhw
# of Israel; for t ||  am` if`p`ed`ed`
# hey are at
# hand  || l` d`wh`el`d`ej`
# to come.
#
# 36:9 F || `d am``(fmbt``e`
# or, behold, I am || ae``md` aod eheb
#  for you, and I  || je `md `m`dh```i
# will turn unto y || `d ed`e`d``lm```
# ou, and ye shall || adfdm``op e`ed``
#
# be tilled and s || `f``d``ie` iedd`
# own: 36:10 And I || id `aed`d`e`dm``
#  will multiply m || `eh ``at `d`d `e
# en upon you, all || ``ejd``aaae`do``
#  the
# house of Is || d `````ad`ob`d `
# rael, even all o || `e dh``ad``eel``
# f it: and the ci || d `hed `ha`d`a``
# ties shall be in || `o`t`ee``id`ea``
# habited,
# and the || ``ad`ald `ee`d``
#  wastes shall be || eeed`eju g  imd
#  builded: 36:11  || ha`agd```id d`d
# And I will multi || `e```ed dh``lmf
# ply upon you
# man || `a``he `id`d`ed`
#  and beast; and  || d`e``lhd ek```dh
# they shall incre || e``whdna`me dl`d
# ase and bring fr || hd `e``h```deg `
# uit: and I will
#  || `aku `d`eha``e``
# settle you after || ``e``ebd`ae`d`md
#  your old estate || `dd`eddd ehe` `m
# s, and will do b || alh `en  dn`d```
# etter unto you t || `d`t````ejd``mf
# han at
# your begi || ``bd eoed`amd``a
# nnings: and ye s || `f` pie `igd e`e
# hall know that I || ``d`a`e``e``e``a
#  am the LORD.
#
# 3 || bd `d`eh``e fhd`
# 6:12 Yea, I will || eddd``mod pd`a``
#  cause men to wa || `d``d`p`o``l```d
# lk upon you, eve || d``e`dhedd cn!p`
# n my people Isra || `ee```m``e`aml``
# el;
# and they sha || d` `je aid `elda
# ll possess thee, || ``bdav `e`d `m``
#  and thou shalt  || ee ahd om `ml `i
# be their inherit || haddaded`ie `ka`
# ance, and
# thou s || d`go p`e`d``u `o
# halt no more hen || ed``d adg `d` dh
# ceforth bereave  || `ehep`eiid`aled`
# them of men.
#
# 36 || ``ld`d`e`d`e```m
# :13 Thus saith t || ee`aled`ejd en `
# he Lord GOD; Bec ||  pld``amd`mde d`
# ause they say un || id``e``id `ol bh
# to you, Thou lan || `dig end `g` `he
# d
# devourest up m || aedd eod `ace`dl
# en, and hast ber || `d`and`qe`dheja`
# eaved thy nation || ```ed`d`qladd`de
# s: 36:14 Therefo || `ed `hg `m``lnd`
# re thou
# shalt de || k` d`d``e```e``d
# vour men no more || `ln `ehd`ee`ehd`
# , neither bereav || ade`e`d`md aoe `
# e thy nations an || `uh`ed`ld``on `n
# y more, saith
# th || dnddn `hfhet  nm
# e Lord GOD.
#
# 36: || hd bh```e`dd`e`e
# 15 Neither will  ||  d````mhv `o thd
# I cause men to h || ed al`d``gd ao `
# ear in thee the  || hehpho"``ie``oa`
# shame of the
# hea || `amd `oe `od `nd
# then any more, n || ie d d`ff `me!`i
# either shalt tho || d`ad`d`ehe`ced `
# u bear the repro ||  hho  u`dedacm `
# ach of the peopl || ed``lddeae`ald d
# e
# any more, neit || dld`````d`ee``je
# her shalt thou c || `ah``e` thed`ael
# ause thy nations || `e`dhd`da dad` e
#  to fall any mor || ```f d `l`g`d```
# e, saith
# the Lor || ````ddhg` `ead f
# d GOD.
#
# 36:16 Mo || ``abdu d`be `ie`
# reover the word  || ehd cg d`e` a```
# of the LORD came || ed` lld hd`e d`e
#  unto me, saying || `g```md``m``mf g
# , 36:17 Son of
# m ||  eh`ad`dl$pe`d``
# an, when the hou || ed`ddadd``ed eh`
# se of Israel dwe || gf dm```e`eed `g
# lt in their own  || `h```ad`ld`lle d
# land, they defil || `e`dh`e`ed an `i
# ed it
# by their o || `md `d``ahg thd`
# wn way and by th ||  pie```d``w`a`lt
# eir doings: thei || ed phd``e`e``e`e
# r way was before || `eh`ho  `d `id`
#  me as the
# uncle || het`efd mld0he`e
# anness of a remo || d`dhd`n `mh  g`a
# ved woman.
#
# 36:1 || ebel aed``dhd`hd
# 8 Wherefore I po || `aheda`de``d````
# ured my fury upo || `gn$ oe dkd ``ad
# n them for the b || `id``ad`dhad mf
# lood that they h || ``ml `he  amd``m
# ad
# shed upon the || `d`ed``ola`ad ag
#  land, and for t || daed`ao````me `m
# heir idols where || `abeld @e `md```
# with they had po || `al``im``ked `ac
# lluted
# it: 36:19 || dadd ee``ho`d``d
#  And I scattered || `ie``d`ee```ld``
#  them among the  ||  `edd`ae`d`ad`eh
# heathen, and the || `ed`aml`e `cn` f
# y were
# dispersed || en``l``u`tmddd`m
#  through the cou || fd``af` `md````a
# ntries: accordin || `f `idd`addhd`e`
# g to their way a || ```hm` the am`dh
# nd according
# to  || `lee`d`e`el`af`e
# their doings I j || `mfd ghd dn` he`
# udged them.
#
# 36: || ad```l``dmd da`d
# 20 And when they || `e$ ifd`e```ng `
#  entered unto th || `u``ale``md he`d
# e heathen, whith || dd``e``m`d`ag `m
# er they went, th || `a``ldd`pim``d`e
# ey
# profaned my h || e```ed`ict `h!pd
# oly name, when t || ```dh`d`e`d`ao``
# hey said to them || an  od u ae```d`
# , These are the  || a`d`dla`hg``ddd`
# people of
# the LO || `eddhe`d`aeddd``
# RD, and are gone || hg `aj`bt`t`dh``
#  forth out of hi || e``kld a`av`e`d`
# s land.
#
# 36:21 B || `md hoe`hmd addd
# ut I had pity fo || hdd `h`d``ond `g
# r mine holy name || `eef dml  mm thw
# , which the hous || i`ajd```e`d`ad`e
# e of Israel had
#  || ```d`elie``ie``e
# profaned among t || `med ehd age``cd
# he heathen, whit || ```p`u```d`dl``a
# her they went.
#
#  ||  dheh$`ee `ae``d
# 36:22 Therefore  || eod amd `0agd eh
# say unto the hou || d`e``md``e`ee```
# se of Israel, th || @g``a``he`dded`d
# us saith the Lor || ```a`eh`a` hd`f`
# d GOD;
# I do not  || die``g`d`e`d```e
# this for your sa || add`md`uj$ hgcd
# kes, O house of  || `d adh `eef`hg``
# Israel, but for  || g```dd`e`daddb`e
# mine holy
# name's || d al `hd`da`eada
#  sake, which ye  || dad`eld```` bd`d
# have profaned am || od``e``````e`d`d
# ong the heathen, || ``av eid``dhee`a
#  whither ye
# went ||  ehddp`ed`e`d`e`
# .
#
# 36:23 And I w || `ald`hddied``ad`
# ill sanctify my  || d`e`d`dd`d`ie``d
# great name, whic ||  dll `ied``ae`a`
# h was profaned a || `od  ad`a`eed`a`
# mong the
# heathen || d``md`d`dhe`a`e`
# , which ye have  || d`a`d`dcg uh`ie
# profaned in the  || ``ef  fe` h`e``m
# midst of them; a || `dhd``m` pe``a``
# nd the heathen
# s || d``ed``e ee`dd``
# hall know that I || aoB hg p`ee`dl`a
#  am the LORD, sa || `j``e``ae```ded`
# ith the Lord GOD || d `me `if dae `d
# , when I shall b ||   ``eu``gha``ar`
# e
# sanctified in  || ``nd `ad `medhgf
# you before their || de`edddhf`da`a e
#  eyes.
#
# 36:24 Fo || e``ehd`ao``ed`bd
# r I will take yo ||  eb``ba`` gf```e
# u from among the || `dd`dad``led`ee`
#  heathen, and ga ||  `ap`e```md`adh`
# ther you out
# of  || ed `o``o``d`e`d`
# all countries, a || b`ed q`m `dmd`eb
# nd will bring yo || au``dmd `med nhd
# u into your own  || `ae" wh``a`e``t`
# land.
#
# 36:25 The || `d`ad`e`aad`ag`e
# n will I sprinkl || ```f``end okd `a
# e clean water up ||  `e`d`e``e`d`ma`
# on you, and ye s || dd`d`e dle ``w`
# hall be
# clean: f || n`db ef `he`d``g
# rom all your fil || `e```dd(wnd```e`
# thiness, and fro || e`b0`aed u`e`e`d
# m all your idols || ```hd``ahe``agd`
# , will I
# cleanse || md`ddead``sap di
#  you.
#
# 36:26 A n || ```ed`g`dhd``d``
# ew heart also wi || `ea``a`d`he`do``
# ll I give you, a || d`ag``ld`head`dd
# nd a new spirit  || ```` eh`e`gl ``a
# will I put
# withi || g``dled gha`me``
# n you: and I wil || hd`e e```d`ie``g
# l take away the  || d `mf `ied``gat`
# stony heart out  || md``d``ead`ead``
# of your flesh,
# a || `ale"Bam  ``ep f
# nd I will give y || e``l`pd``e``ie``
# ou an heart of f || `gh`hod id``hd`e
# lesh.
#
# 36:27 And || ed abd `mf hmd``
#  I will put my s || ld d`dd`dd`e`d`e
# pirit within you || ```d ake v`ed `m
# , and cause you  || ``d aa`af``ae``a
# to walk in my
# st || d tou` me `ig ph
# atutes, and ye s || `e`ahe``d d```eh
# hall keep my jud || e``ie`adhd``aela
# gments, and do t || he ``cd`hldaba``
# hem.
#
# 36:28 And  ||  ehel`e``agd`eld
# ye shall dwell i || d`dl```d`e`aw`dh
# n the land that  || end mn$ im`e`ehe
# I gave to your f || ``ed `md``ma`e``
# athers; and
# ye s || `md``el`eh`am` `
# hall be my peopl || bd``id``o``ll``a
# e, and I will be || og `edd`Ib```d u
#  your God.
#
# 36:2 || l  l``hde uat rh
# 9 I will also sa || aa`dled`a``abe`d
# ve you from all  || oe `dp```el`hf`b
# your uncleanness || d``he `oe `iu``i
# es: and I will
# c || ``awld`l``ehg`aw
# all for the corn || l `and``od md e`
# , and will incre || `fl`jaid `el$ ig
# ase it, and lay  || e`d`dd``f `nb``c
# no famine upon y ||  `ced `md `lap`a
# ou.
#
# 36:30 And I || ```n`````dg `m``
#  will multiply t || ```add ```a``md`
# he fruit of the  || lhat end`al````e
# tree, and the in || dddld`d mh` dedd
# crease of
# the fi || hgd`mf```aald```
# eld, that ye sha || `g`d`m`$`mg d``a
# ll receive no mo || hm  `ov um`d`ehd
# re reproach of f || ad did`hd e`d`da
# amine among the
#  || `ag( `md`ad`e`a`
# heathen.
#
# 36:31  || uaehed`ehd``ed`d
# Then shall ye re || ie `md e```he `h
# member your own  || `f`fd`e`t add`he
# evil ways, and y || d``lm `igd  mod
# our doings that
#  || bdaon  o  `` ada
# were not good, a ||  f G`we `mhe``e`
# nd shall lothe y || `e``ldd``dd`aa`e
# ourselves in you || o  aol pied`hm``
# r own sight for  || ad`b`llav ge w(e
# your
# iniquities  || `ab``e dh`d`a`aa
# and for your abo || o``d(e dd t`e```
# minations.
#
# 36:3 || m```md`aadded``l
# 2 Not for your s ||  p`ebd`eaed `o`d
# akes do I this,  || hf`le```ce`aeld`
# saith the Lord G || ed``ee0 had a`d
# OD, be it known
#  || adddl``g`t``ed`e
# unto you: be ash ||  dha2ae"ad` p
# amed and confoun || `md `ied`aade``a
# ded for your own || ``d``d`e` dhghda
#  ways, O house o || l`ehght qm` eh``
# f
# Israel.
#
# 36:33 || mddd`gd gddher`d
#  Thus saith the  || de``m``acd`el``h
# Lord GOD; In the || dhe`ap`df````ah`
#  day that I shal || `aed `l `le `m`a
# l have cleansed
#  || `el `b``ulbd`o``
# you from all you || ae``a`g`d die am
# r iniquities I w || ```d`d`o```ed al
# ill also cause y || `e``d`em` agd`ha
# ou to dwell in t || ``add`dh`dbe`a``
# he
# cities, and t || ``ace`fhe`dd`l`d
# he wastes shall  || e``f`d``h`g``od`
# be builded.
#
# 36: || l `je$`ee` g`u e
# 34 And the desol || a`d`ev`d`g``m` h
# ate land shall b || alad`a```od `e``
# e tilled, wherea || ad``dag ajda`ed
# s it lay desolat || hg `hq ehd``e`ee
# e
# in the sight o || d`gn `m```eled``
# f all that passe || `hed$`od ed`ad`d
# d by.
#
# 36:35 And || h`hmd amd `ade p
#  they shall say, ||  e amd`hwhe`fd p
#  This land that  || d`dhd``d`e` gnd`
# was desolate is  || e `m`d `eht`ed``
# become like
# the  || aen`aeet am  h`d
# garden of Eden;  || dae`d`heb bmddhh
# and the waste an || 0`mf `edda`e`dn`
# d desolate and r || ead`eddd`ahed`el
# uined cities are || dd`ll`d`dd```dd`
#
# become fenced,  || `d`p`ed`e `d`a``
# and are inhabite || he dnd`he `rb ``
# d.
#
# 36:36 Then t || an```d``hd`af```
# he heathen that  || hd `ev `ad``ie``
# are left round a || fdda ol `he```ah
# bout you shall k || ``dhml `je``a`dd
# now that I
# the L || md p`e`d`e``dd``
# ORD build the ru || ad`````m```e``he
# ined places, and || ed`m``dd`l```d `
#  plant that that || dh`fd``r``ae``l`
#  was desolate: I || d`ld`da``me `mmd
#
# the LORD have s || e`dddd`mdp`ed `h
# poken it, and I  || ``ao$ ae`d enddd
# will do it.
#
# 36: ||  pada```og `e` d
# 37 Thus saith th || d`ald aol `mn$ a
# e Lord GOD; I wi ||  `ge and `hd `le
# ll yet for this  || `ecgdee`d`e``e d
# be enquired of b || d`e`t `m```md dh
# y
# the house of I || he `f`aj``ad`edd
# srael, to do it  || l` ba```de `ho`p
# for them; I will || `a`d af ehe`de``
#  increase them w || ad`d`ehe`e`dd`e`
# ith men
# like a f || `ad``e uhe``g( d
# lock.
#
# 36:38 As  || de @ib`a`d dadd
# the holy flock,  ||  ao  om` eked`d`
# as the flock of  || `a  hd``hd`d`t e
# Jerusalem in her || `ed`e``ddaa`d``a
#  solemn
# feasts;  || gf ane `le``md``
# so shall the was || hd`aheq`m``b`l
# te cities be fil || fa`d`djd``ae``he
# led with flocks  || `e`p`q`e`e``nm d
# of men: and
# they || `f`d``dddd``je `
#  shall know that || `f and0`g`redd``
#  I am the LORD.
#  || `nn``ae `ke`d`e`
#
# 37:1 The hand o || fdbbgd`p`d`ed``e
# f the LORD was u || he `e`d`he ae```
# pon me, and carr || aa`dhd``d ehe`dd
# ied me out in th || amd`aaul `me qju
# e
# spirit of the  || lhe`H!t`w ``d e
# LORD, and set me || hg`bh`ed``dapd`a
#  down in the mid || de```d`d e`eddah
# st of the valley || m``lebd ad``d```
#  which
# was full  || `d``lddhhd `hf``
# of bones, 37:2 A || `e`el`f`ddd`p``a
# nd caused me to  || ``ie``hm`ap```ad
# pass by them rou ||  aaoe e``d`e u`g
# nd about:
# and, b || ```aag` uhe`edl`
# ehold, there wer || a``ed`ad````dddd
# e very many in t || e `am``mmd`hebd`
# he open valley;  || i`d`d``g`ad`e`da
# and, lo, they
# we || `d aded end```d`
# re very dry.
#
# 37 || ``id`efd wha`i`d
# :3 And he said u || ``aed``whdad``d`
# nto me, Son of m || d dn` `in `af` d
# an, can these bo || ``ae` `me`ddad``
# nes live? And I
#  || end em` io`dhg `
# answered, O Lord || d`ehe al`ad`ehd`
#  GOD, thou knowe || aehd thau`de`el`
# st.
#
# 37:4 Again  || `eje($pw e`te`ef
# he said unto me, || `d`ne dko  ie 0`
#  Prophesy upon t || ``eg `io ``add``
# hese bones, and  || d``g`d`ae```m` d
# say unto
# them, O || `da`he`d`he```e
#  ye dry bones, h || `a```ge `ao```am
# ear the word of  || eghd`af a`dadhd`
# the LORD.
#
# 37:5  || `ebd``le d`e`the
# Thus saith the L || `ddeld`die `m`d`
# ord GOD unto the || `a````dd``ae`ded
# se bones; Behold || `m dhul `daat ad
# , I will cause
# b || `d`e```a`ddd`a``
# reath to enter i || au`adb``ld```e`a
# nto you, and ye  ||  `id `ke  iod pa
# shall live: 37:6 || th`hod t``u ub`d
#  And I will lay
#  || `cg```a`d`v u```
# sinews upon you, || bdca``nd ``e ele
#  and will bring  || `a`d`en thed`e e
# up flesh upon yo || ad`ale``d`p`ln t
# u, and cover you || (d`ed`d`e`ajf``d
#  with
# skin, and  || `d p`amt aod``o`
# put breath in yo || ddd `md `ale`dde
# u, and ye shall  || ge``l``m``ed jd`
# live; and ye sha || o`tjmb`t `add`m`
# ll know that
# I a || `ed`b`cv phedae`
# m the LORD.
#
# 37: || bo`d`ced``ad ``f
# 7 So I prophesie ||  phe ead`ighe `a
# d as I was comma || e```e`e`ao``ad d
# nded: and as I p || agdd o`r if``mo
# rophesied, there || af``b``ad`d`edd`
#
# was a noise, an || am``md`a` ed qje
# d behold a shaki || hddp`aid`head``l
# ng, and the bone || `eod omf`d agt b
# s came together, || d``edd``ded`da`d
#  bone
# to his bon || ddid dd```get eh
# e.
#
# 37:8 And whe || ae` `u `me`hm` m
# n I beheld, lo,  || `dld a``e```jdhe
# the sinews and t || hoe4 ll h```dd e
# he flesh came up || abid``gd`ag``h`d
#  upon
# them, and  || dad```md`d`ded`a
# the skin covered || ehd `e dde`pmed
#  them above: but || dp`ed`g``m  `ha`
#  there was no br || ad`eh```e`a`af``
# eath in
# them.
#
# 3 ||  `d`d`ae`e`aed``
# 7:9 Then said he || ehe`el sh``a`ld`
#  unto me, Prophe || a``ae  mad`aehe
# sy unto the wind || `d`eht`am `df```
# , prophesy, son  || ``abd`t``l``ehg`
# of
# man, and say  || e(eha`edae`vfe``
# to the wind, Thu || dl` al`pheo dhe`
# s saith the Lord || d`a`ed`lhdhuhd``
#  GOD; Come from  || vl f qn``ag`bd`d
# the four
# winds,  || ``hed atd```l```
# O breath, and br || `a``lf ama``ae `
# eathe upon these || ed and`a`e```ad`
#  slain, that the || `od  da`d`e`fav`
# y may live.
#
# 37: || ``aef$ oo$ `e`t`
# 10 So I prophesi || `e```g`dm `mdd e
# ed as he command || f``mo``aged `g``
# ed me, and the b ||  ehe``ie`ej` a `
# reath came into
#  || `eav(ujd m`e`d`e
# them, and they l || de`aod `ia `la``
# ived, and stood  || `hod `oit ao``ie
# up upon their fe || `he `el `l`e`d`e
# et, an exceeding || od``id g `ie `ie
#  great
# army.
#
# 37 || ``d`ajd`fe `dh `
# :11 Then he said || be``av`m`` en``h
#  unto me, Son of || ed(a`d`eb`ka`p `
#  man, these bone || `d eja``hl  e(t`
# s are the whole
#  || ed`e`en`dd `ejdh
# house of Israel: || md `nd``de`emd``
#  behold, they sa || d`ed```e`d`el```
# y, Our bones are || d`ahd``he``ele a
#  dried, and our  ||  `hm ehee`d`ad`e
# hope
# is lost: we || he eld`ao`p`r`t`
#  are cut off for || de`b ohw` ehe``d
#  our parts.
#
# 37: || `dhw pka` ete `e
# 12 Therefore pro || `og`bejd ~ av``e
# phesy and say un ||  uhad`el ehed eh
# to them, Thus sa || w Ehad``l`v`gd e
# ith the Lord GOD || d````e al`dl`d`e
# ;
# Behold, O my p || h``da`d``a`e`d``
# eople, I will op || ed ejd eh`an``e`
# en your graves,  || ef`e`v``add`gd a
# and cause you to || ae` al`a``dm`d`a
#  come up
# out of  || mf`g`d `l`d eh``
# your graves, and || ` `o` hg ejad``e
#  bring you into  || `ad``a`dd`ae`a`d
# the land of Isra || l` ml `he`t`nf a
# el.
#
# 37:13 And y || daf```o p a```ud
# e shall know tha || d am`d`eed`hg d`
# t I am the LORD, || `e fn rhe e`ded`
#  when I have ope || h``ke ekd dhgd `
# ned your
# graves, || j` on the ```f``
#  O my people, an || dl`d(ehdh `md``m
# d brought you up || `c`abd```ad`d`ed
#  out of your gra || d```de`d`add`eff
# ves, 37:14 And
# s || he d``ehg `n`phd
# hall put my spir || ehd oo th `he `d
# it in you, and y || ``ea`be`````d`dl
# e shall live, an || aadane p`e``dheh
# d I shall place  || `h`aefe``d```w`d
# you
# in your own  || `e`de`d`o`pe`d``
# land: then shall || `l```ehat a`dgda
#  ye know that I  || dd`did``m em`t`e
# the LORD have sp || `ae``fdee`d`me(a
# oken it,
# and per || `eb``gdd`oed e`a
# formed it, saith || he```d``` v``j``
#  the LORD.
#
# 37:1 || ``ad kl```d `m`b
# 5 The word of th || dl `n  ehd eme d
# e LORD came agai || he`dd`ed`eldd``u
# n unto me, sayin || `d``he ``he e``j
# g, 37:16 Moreove || `e``ie``bma`pd`d
# r,
# thou son of m || `d```oo$0`be```g
# an, take thee on || n( Nhp uhehe`dd`

# %%
save_model(neural_network, 'aes_feedforward')
